# %% [markdown]
# # Group C : Jing Wang,Vikash Bajiya, Deviprasad Saka
# # Classification Project : Histopathologic-cancer-detection

# %% [markdown]
# 1. **Problem Statement**
#     - Histopathologic cancer detection involves identifying metastatic cancer in small image patches extracted from larger pathology scans. Accurate detection aids in timely diagnosis and treatment planning.
# 2. **Objective**
#     - To design and evaluate multiple machine learning models for binary image classification, leveraging advanced preprocessing, augmentation,and optimization techniques.
# 3. **Dataset**
#     - The dataset consists of 32x32-pixel pathology images labeled as positive (cancerous) or negative (non-cancerous).
#     - Dataset Link- https://www.kaggle.com/c/histopathologic-cancer-detection/data
#
# ###  Model Design and Implementation
#
# Six models were designed, trained, and evaluated to identify the most effective classifier:
#
# - **Naive Bayes**
# - **Random Forest**
# - **Logistic Regression**
# - **Support Vector Machine (SVM)**
# - **Neural Network**
# - **XGBoost (Not covered in class)**

# %% [markdown]
# ## 1. Data Processing

# %%
# General purpose libraries
import os
import glob
import gc
import pickle
import random
import numpy as np
import pandas as pd

# Data Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Image handling
from PIL import Image
from torchvision import transforms

# Data preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# Model evaluation and training
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    confusion_matrix,
    precision_recall_curve,
    roc_curve,
    auc
)

# Machine learning models
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV

# Advanced techniques
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier

# Deep learnibg libraries
import torch
import torch.nn as nn
import torch.optim as optim

# Saving and loading models
from joblib import dump, load

# %% [markdown]
# ### 1.1 Data Cleaning

# %% [markdown]
# - Verified consistency between the dataset and the label file.
# - Identified and removed missing, extra, or corrupted images.
# - Ensured there were no duplicate images in the dataset.

# %%
# Define the main directory where all data for the project is stored
data_dir = "histopathologic-cancer-detection"

# Define paths to the subdirectories and important files
train_dir = os.path.join(data_dir, "train")
test_dir = os.path.join(data_dir, "test")
train_labels_path = os.path.join(data_dir, "train_labels.csv")
sample_submission_path = os.path.join(data_dir, "sample_submission.csv")

# Load the training labels file into a pandas DataFrame
train_labels = pd.read_csv(train_labels_path)

# Check for missing values in the labels file
missing_values = train_labels.isnull().sum()
print("Missing values in train_labels.csv:")
print(missing_values)

# Get the list of image files in the training directory
train_files = set(os.listdir(train_dir))


# Get the list of image file names mentioned in the labels file
# Add ".tif" extension since the images are in TIFF format
train_labels_files = set(train_labels["id"] + ".tif")

# Find images mentioned in the labels file but missing in the training directory
missing_files = train_labels_files - train_files

# Find images that are in the training directory but not mentioned in the labels file
extra_files = train_files - train_labels_files

# Print the count of missing and extra files
print(f"Number of missing images: {len(missing_files)}")
print(f"Number of extra images: {len(extra_files)}")

# Function to check if image files are valid (not corrupted)
def check_image_validity(image_dir, file_set):
    invalid_images = []
    for file_name in file_set:
        file_path = os.path.join(image_dir, file_name)
        try:
            with Image.open(file_path) as img:
                img.verify()
        except (IOError, SyntaxError):
            invalid_images.append(file_name)
    return invalid_images

# Check for damaged or invalid image files in the training directory
invalid_train_images = check_image_validity(train_dir, train_files)

# Print the number of damaged image files found
print(f"Number of damaged training images: {len(invalid_train_images)}")

# Save the cleaned labels file to a new CSV file
# This file can later be used for training the model
train_labels.to_csv(os.path.join(data_dir, "cleaned_train_labels.csv"), index=False)
# Out:
# Missing values in train_labels.csv:
# id       0
# label    0
# dtype: int64
# Number of missing images: 0
# Number of extra images: 0
# Number of damaged training images: 0

# %% [markdown]
# ### 1.2 Exploratory Data Analysis (EDA)

# %% [markdown]
# #### 1.2.1 Data Visualization

# %%
# Convert train_labels data into a pandas DataFrame with two columns: "id" and "label"
train_labels = pd.DataFrame(train_labels, columns=["id", "label"])

# Display the first few rows of the train_labels DataFrame to check its content
display(train_labels.head())

# Define a function to display sample images along with their labels
def display_sample_images_fixed(image_ids, directory, labels, rows=4, cols=5):
    sample_ids = random.sample(list(image_ids), rows * cols)
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 2, rows * 2))  
    axes = axes.flatten()

    for i, image_id in enumerate(sample_ids):
        img_path = os.path.join(directory, image_id + ".tif")
        label = labels.loc[labels["id"] == image_id, "label"].values[0]
        img = Image.open(img_path)
        axes[i].imshow(img)
        axes[i].set_title(f"Label: {label}", fontsize=10)
        axes[i].axis("off")
    plt.tight_layout(pad=1.0)
    plt.show()

# Call the function to display 4 rows and 5 columns of sample images with their labels
display_sample_images_fixed(train_labels["id"], train_dir, train_labels, rows=4, cols=5)
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %% [markdown]
# 1. **Label 0**
#     - Represents a negative sample, where the patch does not contain metastatic cancer. Negative samples tend to have more uniform structures or appear lighter in texture.
#
# 2. **Label 1**
#     - Represents a positive sample, indicating the presence of metastatic cancer. Positive samples often exhibit denser cell clusters and darker regions, suggesting the presence of cancer.
#
# - This dataset forms the foundation for training and evaluating our machine learning models, with a focus on binary classification for detecting metastatic cancer.

# %% [markdown]
# #### 1.2.2 Analyze Sample Distribution

# %%
# Count the number of positive samples (where the label is 1) in the training labels
# Count the number of negative samples (where the label is 0) in the training labels
positive_count = train_labels.loc[train_labels['label'] == 1].shape[0]
negative_count = train_labels.loc[train_labels['label'] == 0].shape[0]
print(f"Positive samples: {positive_count}, Negative samples: {negative_count}")

labels = ['Positive', 'Negative']
counts = [positive_count, negative_count]
colors = ['blue', 'orange']
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=70)
plt.title('Positive vs Negative Sample Distribution')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - The dataset is characterized by a class imbalance, with significantly more negative samples than positive samples. To mitigate this, techniques like SMOTE (Synthetic Minority Oversampling Technique) and data augmentation were applied during analytics.

# %% [markdown]
# #### 1.2.3 Analyze Positive and Negative Sample Features

# %%
# Compare RGB channels, brightness for positive and negative samples
def calculate_channel_and_brightness_means(image_ids, directory):
    red_means, green_means, blue_means, brightness_means = [], [], [], []
    for img_id in image_ids:
        img_path = os.path.join(directory, img_id + ".tif")
        img = np.array(Image.open(img_path))
        red_means.append(img[:, :, 0].mean())
        green_means.append(img[:, :, 1].mean())
        blue_means.append(img[:, :, 2].mean())
        brightness_means.append(img.mean())  
    return red_means, green_means, blue_means, brightness_means

positive_ids = train_labels[train_labels['label'] == 1]['id'].values
negative_ids = train_labels[train_labels['label'] == 0]['id'].values
pos_red, pos_green, pos_blue, pos_brightness = calculate_channel_and_brightness_means(positive_ids, train_dir)
neg_red, neg_green, neg_blue, neg_brightness = calculate_channel_and_brightness_means(negative_ids, train_dir)
features = {
    "Red": (pos_red, neg_red),
    "Green": (pos_green, neg_green),
    "Blue": (pos_blue, neg_blue),
    "Brightness": (pos_brightness, neg_brightness)
}

plt.figure(figsize=(12, 8))
for i, (feature_name, (pos_values, neg_values)) in enumerate(features.items(), 1):
    plt.subplot(2, 2, i)
    plt.hist(pos_values, bins=50, alpha=0.5, label='Positive', color='blue', density=True)
    plt.hist(neg_values, bins=50, alpha=0.5, label='Negative', color='orange', density=True)
    plt.title(feature_name)
    plt.xlabel('Value')
    plt.ylabel('Relative Frequency')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Distributions of color channel values (Red, Green, Blue) and overall brightness.**
# - Red Panel: Cancer samples ("Positive," blue) and non-cancer samples ("Negative," orange) show slightly overlapping distributions. However, the blue area tends to lean toward higher red values compared to the orange.
# - Green Panel: Similar to the red panel, but with a more distinct shift. Positive samples tend to have higher green intensity values than negative ones.
# - Blue Panel: Positive samples have a narrower range, clustered around higher blue values, while negative samples show a wider spread.
# - Brightness Panel: Positive samples tend to be brighter overall, as seen by the shift of the blue distribution toward higher brightness values.

# %% [markdown]
# ### 1.3 Dataset Preprocessing

# %% [markdown]
# #### 1.3.1 Split Dataset

# %%
# Split the training data into two parts: 80% for training (train_set),  20% for validation (val_set)
train_set, val_set = train_test_split(train_labels, test_size=0.2, stratify=train_labels["label"], random_state=42)

# Print the size of the training and validation sets
print(f"Training set size: {len(train_set)}")
print(f"Validation set size: {len(val_set)}")

train_ids = train_set["id"].values
val_ids = val_set["id"].values
train_labels = train_set["label"].values
val_labels = val_set["label"].values
# Out:
# Training set size: 176020
# Validation set size: 44005

# %% [markdown]
# #### 1.3.2 Batch Processing and Saving

# %%
# Function to process and save data in batches
def process_and_save_batches(image_ids, labels, directory, func, batch_size, output_file):

    #  Check for Already Processed Batches
    existing_batches = set(glob.glob(f"{output_file}_batch_*.pkl"))
    print(f"Found {len(existing_batches)} existing batches. Starting processing...")
    
    # Process Each Batch
    for i in range(0, len(image_ids), batch_size):
        # Check and Skip Processed Batches
        batch_file = f"{output_file}_batch_{i // batch_size}.pkl"
        if batch_file in existing_batches:
            print(f"Skipping already processed batch: {batch_file}")
            continue
        # Process the Current Batch   
        batch_ids = image_ids[i:i + batch_size]
        batch_labels = labels[i:i + batch_size]
        batch_data = np.array([func(img_id, directory) for img_id in batch_ids])
        #  Save the Batch
        with open(batch_file, "wb") as f:
            pickle.dump((batch_data, batch_labels), f)
        print(f"Saved: {batch_file}")
        # Clean Up
        del batch_data, batch_labels
        gc.collect()
    print("All batches processed.")

# %% [markdown]
# - When working with large datasets, especially image datasets, batch processing and saving are crucial techniques for efficiently managing memory, processing time and data reusability.

# %% [markdown]
# #### 1.3.3 Flatten images (For Naive Bayes and Random Forest)

# %%
# Defines the number of images to process at a time. This helps manage memory usage and speeds up processing.
BATCH_SIZE = 400
# Function to flatten an image into a 1D array
def flatten_image(img_id, directory):
    img_path = os.path.join(directory, img_id + ".tif")
    img = Image.open(img_path)
    return np.array(img).flatten()
# Process and save batches of training and validation data    
process_and_save_batches(train_ids, train_labels, train_dir, flatten_image, BATCH_SIZE, "train_raw")
process_and_save_batches(val_ids, val_labels, train_dir, flatten_image, BATCH_SIZE, "val_raw")
print("Processing complete. Exiting now.")
# Out:
# Found 0 existing batches. Starting processing...
# Saved: train_raw_batch_0.pkl
# Saved: train_raw_batch_1.pkl
# Saved: train_raw_batch_2.pkl
# Saved: train_raw_batch_3.pkl
# Saved: train_raw_batch_4.pkl
# Saved: train_raw_batch_5.pkl
# Saved: train_raw_batch_6.pkl
# Saved: train_raw_batch_7.pkl
# Saved: train_raw_batch_8.pkl
# Saved: train_raw_batch_9.pkl
# Saved: train_raw_batch_10.pkl
# Saved: train_raw_batch_11.pkl
# Saved: train_raw_batch_12.pkl
# Saved: train_raw_batch_13.pkl
# Saved: train_raw_batch_14.pkl
# Saved: train_raw_batch_15.pkl
# Saved: train_raw_batch_16.pkl
# Saved: train_raw_batch_17.pkl
# Saved: train_raw_batch_18.pkl
# Saved: train_raw_batch_19.pkl
# Saved: train_raw_batch_20.pkl
# Saved: train_raw_batch_21.pkl
# Saved: train_raw_batch_22.pkl
# Saved: train_raw_batch_23.pkl
# Saved: train_raw_batch_24.pkl
# Saved: train_raw_batch_25.pkl
# Saved: train_raw_batch_26.pkl
# Saved: train_raw_batch_27.pkl
# Saved: train_raw_batch_28.pkl
# Saved: train_raw_batch_29.pkl
# Saved: train_raw_batch_30.pkl
# Saved: train_raw_batch_31.pkl
# Saved: train_raw_batch_32.pkl
# Saved: train_raw_batch_33.pkl
# Saved: train_raw_batch_34.pkl
# Saved: train_raw_batch_35.pkl
# Saved: train_raw_batch_36.pkl
# Saved: train_raw_batch_37.pkl
# Saved: train_raw_batch_38.pkl
# Saved: train_raw_batch_39.pkl
# Saved: train_raw_batch_40.pkl
# Saved: train_raw_batch_41.pkl
# Saved: train_raw_batch_42.pkl
# Saved: train_raw_batch_43.pkl
# Saved: train_raw_batch_44.pkl
# Saved: train_raw_batch_45.pkl
# Saved: train_raw_batch_46.pkl
# Saved: train_raw_batch_47.pkl
# Saved: train_raw_batch_48.pkl
# Saved: train_raw_batch_49.pkl
# Saved: train_raw_batch_50.pkl
# Saved: train_raw_batch_51.pkl
# Saved: train_raw_batch_52.pkl
# Saved: train_raw_batch_53.pkl
# Saved: train_raw_batch_54.pkl
# Saved: train_raw_batch_55.pkl
# Saved: train_raw_batch_56.pkl
# Saved: train_raw_batch_57.pkl
# Saved: train_raw_batch_58.pkl
# Saved: train_raw_batch_59.pkl
# Saved: train_raw_batch_60.pkl
# Saved: train_raw_batch_61.pkl
# Saved: train_raw_batch_62.pkl
# Saved: train_raw_batch_63.pkl
# Saved: train_raw_batch_64.pkl
# Saved: train_raw_batch_65.pkl
# Saved: train_raw_batch_66.pkl
# Saved: train_raw_batch_67.pkl
# Saved: train_raw_batch_68.pkl
# Saved: train_raw_batch_69.pkl
# Saved: train_raw_batch_70.pkl
# Saved: train_raw_batch_71.pkl
# Saved: train_raw_batch_72.pkl
# Saved: train_raw_batch_73.pkl
# Saved: train_raw_batch_74.pkl
# Saved: train_raw_batch_75.pkl
# Saved: train_raw_batch_76.pkl
# Saved: train_raw_batch_77.pkl
# Saved: train_raw_batch_78.pkl
# Saved: train_raw_batch_79.pkl
# Saved: train_raw_batch_80.pkl
# Saved: train_raw_batch_81.pkl
# Saved: train_raw_batch_82.pkl
# Saved: train_raw_batch_83.pkl
# Saved: train_raw_batch_84.pkl
# Saved: train_raw_batch_85.pkl
# Saved: train_raw_batch_86.pkl
# Saved: train_raw_batch_87.pkl
# Saved: train_raw_batch_88.pkl
# Saved: train_raw_batch_89.pkl
# Saved: train_raw_batch_90.pkl
# Saved: train_raw_batch_91.pkl
# Saved: train_raw_batch_92.pkl
# Saved: train_raw_batch_93.pkl
# Saved: train_raw_batch_94.pkl
# Saved: train_raw_batch_95.pkl
# Saved: train_raw_batch_96.pkl
# Saved: train_raw_batch_97.pkl
# Saved: train_raw_batch_98.pkl
# Saved: train_raw_batch_99.pkl
# Saved: train_raw_batch_100.pkl
# Saved: train_raw_batch_101.pkl
# Saved: train_raw_batch_102.pkl
# Saved: train_raw_batch_103.pkl
# Saved: train_raw_batch_104.pkl
# Saved: train_raw_batch_105.pkl
# Saved: train_raw_batch_106.pkl
# Saved: train_raw_batch_107.pkl
# Saved: train_raw_batch_108.pkl
# Saved: train_raw_batch_109.pkl
# Saved: train_raw_batch_110.pkl
# Saved: train_raw_batch_111.pkl
# Saved: train_raw_batch_112.pkl
# Saved: train_raw_batch_113.pkl
# Saved: train_raw_batch_114.pkl
# Saved: train_raw_batch_115.pkl
# Saved: train_raw_batch_116.pkl
# Saved: train_raw_batch_117.pkl
# Saved: train_raw_batch_118.pkl
# Saved: train_raw_batch_119.pkl
# Saved: train_raw_batch_120.pkl
# Saved: train_raw_batch_121.pkl
# Saved: train_raw_batch_122.pkl
# Saved: train_raw_batch_123.pkl
# Saved: train_raw_batch_124.pkl
# Saved: train_raw_batch_125.pkl
# Saved: train_raw_batch_126.pkl
# Saved: train_raw_batch_127.pkl
# Saved: train_raw_batch_128.pkl
# Saved: train_raw_batch_129.pkl
# Saved: train_raw_batch_130.pkl
# Saved: train_raw_batch_131.pkl
# Saved: train_raw_batch_132.pkl
# Saved: train_raw_batch_133.pkl
# Saved: train_raw_batch_134.pkl
# Saved: train_raw_batch_135.pkl
# Saved: train_raw_batch_136.pkl
# Saved: train_raw_batch_137.pkl
# Saved: train_raw_batch_138.pkl
# Saved: train_raw_batch_139.pkl
# Saved: train_raw_batch_140.pkl
# Saved: train_raw_batch_141.pkl
# Saved: train_raw_batch_142.pkl
# Saved: train_raw_batch_143.pkl
# Saved: train_raw_batch_144.pkl
# Saved: train_raw_batch_145.pkl
# Saved: train_raw_batch_146.pkl
# Saved: train_raw_batch_147.pkl
# Saved: train_raw_batch_148.pkl
# Saved: train_raw_batch_149.pkl
# Saved: train_raw_batch_150.pkl
# Saved: train_raw_batch_151.pkl
# Saved: train_raw_batch_152.pkl
# Saved: train_raw_batch_153.pkl
# Saved: train_raw_batch_154.pkl
# Saved: train_raw_batch_155.pkl
# Saved: train_raw_batch_156.pkl
# Saved: train_raw_batch_157.pkl
# Saved: train_raw_batch_158.pkl
# Saved: train_raw_batch_159.pkl
# Saved: train_raw_batch_160.pkl
# Saved: train_raw_batch_161.pkl
# Saved: train_raw_batch_162.pkl
# Saved: train_raw_batch_163.pkl
# Saved: train_raw_batch_164.pkl
# Saved: train_raw_batch_165.pkl
# Saved: train_raw_batch_166.pkl
# Saved: train_raw_batch_167.pkl
# Saved: train_raw_batch_168.pkl
# Saved: train_raw_batch_169.pkl
# Saved: train_raw_batch_170.pkl
# Saved: train_raw_batch_171.pkl
# Saved: train_raw_batch_172.pkl
# Saved: train_raw_batch_173.pkl
# Saved: train_raw_batch_174.pkl
# Saved: train_raw_batch_175.pkl
# Saved: train_raw_batch_176.pkl
# Saved: train_raw_batch_177.pkl
# Saved: train_raw_batch_178.pkl
# Saved: train_raw_batch_179.pkl
# Saved: train_raw_batch_180.pkl
# Saved: train_raw_batch_181.pkl
# Saved: train_raw_batch_182.pkl
# Saved: train_raw_batch_183.pkl
# Saved: train_raw_batch_184.pkl
# Saved: train_raw_batch_185.pkl
# Saved: train_raw_batch_186.pkl
# Saved: train_raw_batch_187.pkl
# Saved: train_raw_batch_188.pkl
# Saved: train_raw_batch_189.pkl
# Saved: train_raw_batch_190.pkl
# Saved: train_raw_batch_191.pkl
# Saved: train_raw_batch_192.pkl
# Saved: train_raw_batch_193.pkl
# Saved: train_raw_batch_194.pkl
# Saved: train_raw_batch_195.pkl
# Saved: train_raw_batch_196.pkl
# Saved: train_raw_batch_197.pkl
# Saved: train_raw_batch_198.pkl
# Saved: train_raw_batch_199.pkl
# Saved: train_raw_batch_200.pkl
# Saved: train_raw_batch_201.pkl
# Saved: train_raw_batch_202.pkl
# Saved: train_raw_batch_203.pkl
# Saved: train_raw_batch_204.pkl
# Saved: train_raw_batch_205.pkl
# Saved: train_raw_batch_206.pkl
# Saved: train_raw_batch_207.pkl
# Saved: train_raw_batch_208.pkl
# Saved: train_raw_batch_209.pkl
# Saved: train_raw_batch_210.pkl
# Saved: train_raw_batch_211.pkl
# Saved: train_raw_batch_212.pkl
# Saved: train_raw_batch_213.pkl
# Saved: train_raw_batch_214.pkl
# Saved: train_raw_batch_215.pkl
# Saved: train_raw_batch_216.pkl
# Saved: train_raw_batch_217.pkl
# Saved: train_raw_batch_218.pkl
# Saved: train_raw_batch_219.pkl
# Saved: train_raw_batch_220.pkl
# Saved: train_raw_batch_221.pkl
# Saved: train_raw_batch_222.pkl
# Saved: train_raw_batch_223.pkl
# Saved: train_raw_batch_224.pkl
# Saved: train_raw_batch_225.pkl
# Saved: train_raw_batch_226.pkl
# Saved: train_raw_batch_227.pkl
# Saved: train_raw_batch_228.pkl
# Saved: train_raw_batch_229.pkl
# Saved: train_raw_batch_230.pkl
# Saved: train_raw_batch_231.pkl
# Saved: train_raw_batch_232.pkl
# Saved: train_raw_batch_233.pkl
# Saved: train_raw_batch_234.pkl
# Saved: train_raw_batch_235.pkl
# Saved: train_raw_batch_236.pkl
# Saved: train_raw_batch_237.pkl
# Saved: train_raw_batch_238.pkl
# Saved: train_raw_batch_239.pkl
# Saved: train_raw_batch_240.pkl
# Saved: train_raw_batch_241.pkl
# Saved: train_raw_batch_242.pkl
# Saved: train_raw_batch_243.pkl
# Saved: train_raw_batch_244.pkl
# Saved: train_raw_batch_245.pkl
# Saved: train_raw_batch_246.pkl
# Saved: train_raw_batch_247.pkl
# Saved: train_raw_batch_248.pkl
# Saved: train_raw_batch_249.pkl
# Saved: train_raw_batch_250.pkl
# Saved: train_raw_batch_251.pkl
# Saved: train_raw_batch_252.pkl
# Saved: train_raw_batch_253.pkl
# Saved: train_raw_batch_254.pkl
# Saved: train_raw_batch_255.pkl
# Saved: train_raw_batch_256.pkl
# Saved: train_raw_batch_257.pkl
# Saved: train_raw_batch_258.pkl
# Saved: train_raw_batch_259.pkl
# Saved: train_raw_batch_260.pkl
# Saved: train_raw_batch_261.pkl
# Saved: train_raw_batch_262.pkl
# Saved: train_raw_batch_263.pkl
# Saved: train_raw_batch_264.pkl
# Saved: train_raw_batch_265.pkl
# Saved: train_raw_batch_266.pkl
# Saved: train_raw_batch_267.pkl
# Saved: train_raw_batch_268.pkl
# Saved: train_raw_batch_269.pkl
# Saved: train_raw_batch_270.pkl
# Saved: train_raw_batch_271.pkl
# Saved: train_raw_batch_272.pkl
# Saved: train_raw_batch_273.pkl
# Saved: train_raw_batch_274.pkl
# Saved: train_raw_batch_275.pkl
# Saved: train_raw_batch_276.pkl
# Saved: train_raw_batch_277.pkl
# Saved: train_raw_batch_278.pkl
# Saved: train_raw_batch_279.pkl
# Saved: train_raw_batch_280.pkl
# Saved: train_raw_batch_281.pkl
# Saved: train_raw_batch_282.pkl
# Saved: train_raw_batch_283.pkl
# Saved: train_raw_batch_284.pkl
# Saved: train_raw_batch_285.pkl
# Saved: train_raw_batch_286.pkl
# Saved: train_raw_batch_287.pkl
# Saved: train_raw_batch_288.pkl
# Saved: train_raw_batch_289.pkl
# Saved: train_raw_batch_290.pkl
# Saved: train_raw_batch_291.pkl
# Saved: train_raw_batch_292.pkl
# Saved: train_raw_batch_293.pkl
# Saved: train_raw_batch_294.pkl
# Saved: train_raw_batch_295.pkl
# Saved: train_raw_batch_296.pkl
# Saved: train_raw_batch_297.pkl
# Saved: train_raw_batch_298.pkl
# Saved: train_raw_batch_299.pkl
# Saved: train_raw_batch_300.pkl
# Saved: train_raw_batch_301.pkl
# Saved: train_raw_batch_302.pkl
# Saved: train_raw_batch_303.pkl
# Saved: train_raw_batch_304.pkl
# Saved: train_raw_batch_305.pkl
# Saved: train_raw_batch_306.pkl
# Saved: train_raw_batch_307.pkl
# Saved: train_raw_batch_308.pkl
# Saved: train_raw_batch_309.pkl
# Saved: train_raw_batch_310.pkl
# Saved: train_raw_batch_311.pkl
# Saved: train_raw_batch_312.pkl
# Saved: train_raw_batch_313.pkl
# Saved: train_raw_batch_314.pkl
# Saved: train_raw_batch_315.pkl
# Saved: train_raw_batch_316.pkl
# Saved: train_raw_batch_317.pkl
# Saved: train_raw_batch_318.pkl
# Saved: train_raw_batch_319.pkl
# Saved: train_raw_batch_320.pkl
# Saved: train_raw_batch_321.pkl
# Saved: train_raw_batch_322.pkl
# Saved: train_raw_batch_323.pkl
# Saved: train_raw_batch_324.pkl
# Saved: train_raw_batch_325.pkl
# Saved: train_raw_batch_326.pkl
# Saved: train_raw_batch_327.pkl
# Saved: train_raw_batch_328.pkl
# Saved: train_raw_batch_329.pkl
# Saved: train_raw_batch_330.pkl
# Saved: train_raw_batch_331.pkl
# Saved: train_raw_batch_332.pkl
# Saved: train_raw_batch_333.pkl
# Saved: train_raw_batch_334.pkl
# Saved: train_raw_batch_335.pkl
# Saved: train_raw_batch_336.pkl
# Saved: train_raw_batch_337.pkl
# Saved: train_raw_batch_338.pkl
# Saved: train_raw_batch_339.pkl
# Saved: train_raw_batch_340.pkl
# Saved: train_raw_batch_341.pkl
# Saved: train_raw_batch_342.pkl
# Saved: train_raw_batch_343.pkl
# Saved: train_raw_batch_344.pkl
# Saved: train_raw_batch_345.pkl
# Saved: train_raw_batch_346.pkl
# Saved: train_raw_batch_347.pkl
# Saved: train_raw_batch_348.pkl
# Saved: train_raw_batch_349.pkl
# Saved: train_raw_batch_350.pkl
# Saved: train_raw_batch_351.pkl
# Saved: train_raw_batch_352.pkl
# Saved: train_raw_batch_353.pkl
# Saved: train_raw_batch_354.pkl
# Saved: train_raw_batch_355.pkl
# Saved: train_raw_batch_356.pkl
# Saved: train_raw_batch_357.pkl
# Saved: train_raw_batch_358.pkl
# Saved: train_raw_batch_359.pkl
# Saved: train_raw_batch_360.pkl
# Saved: train_raw_batch_361.pkl
# Saved: train_raw_batch_362.pkl
# Saved: train_raw_batch_363.pkl
# Saved: train_raw_batch_364.pkl
# Saved: train_raw_batch_365.pkl
# Saved: train_raw_batch_366.pkl
# Saved: train_raw_batch_367.pkl
# Saved: train_raw_batch_368.pkl
# Saved: train_raw_batch_369.pkl
# Saved: train_raw_batch_370.pkl
# Saved: train_raw_batch_371.pkl
# Saved: train_raw_batch_372.pkl
# Saved: train_raw_batch_373.pkl
# Saved: train_raw_batch_374.pkl
# Saved: train_raw_batch_375.pkl
# Saved: train_raw_batch_376.pkl
# Saved: train_raw_batch_377.pkl
# Saved: train_raw_batch_378.pkl
# Saved: train_raw_batch_379.pkl
# Saved: train_raw_batch_380.pkl
# Saved: train_raw_batch_381.pkl
# Saved: train_raw_batch_382.pkl
# Saved: train_raw_batch_383.pkl
# Saved: train_raw_batch_384.pkl
# Saved: train_raw_batch_385.pkl
# Saved: train_raw_batch_386.pkl
# Saved: train_raw_batch_387.pkl
# Saved: train_raw_batch_388.pkl
# Saved: train_raw_batch_389.pkl
# Saved: train_raw_batch_390.pkl
# Saved: train_raw_batch_391.pkl
# Saved: train_raw_batch_392.pkl
# Saved: train_raw_batch_393.pkl
# Saved: train_raw_batch_394.pkl
# Saved: train_raw_batch_395.pkl
# Saved: train_raw_batch_396.pkl
# Saved: train_raw_batch_397.pkl
# Saved: train_raw_batch_398.pkl
# Saved: train_raw_batch_399.pkl
# Saved: train_raw_batch_400.pkl
# Saved: train_raw_batch_401.pkl
# Saved: train_raw_batch_402.pkl
# Saved: train_raw_batch_403.pkl
# Saved: train_raw_batch_404.pkl
# Saved: train_raw_batch_405.pkl
# Saved: train_raw_batch_406.pkl
# Saved: train_raw_batch_407.pkl
# Saved: train_raw_batch_408.pkl
# Saved: train_raw_batch_409.pkl
# Saved: train_raw_batch_410.pkl
# Saved: train_raw_batch_411.pkl
# Saved: train_raw_batch_412.pkl
# Saved: train_raw_batch_413.pkl
# Saved: train_raw_batch_414.pkl
# Saved: train_raw_batch_415.pkl
# Saved: train_raw_batch_416.pkl
# Saved: train_raw_batch_417.pkl
# Saved: train_raw_batch_418.pkl
# Saved: train_raw_batch_419.pkl
# Saved: train_raw_batch_420.pkl
# Saved: train_raw_batch_421.pkl
# Saved: train_raw_batch_422.pkl
# Saved: train_raw_batch_423.pkl
# Saved: train_raw_batch_424.pkl
# Saved: train_raw_batch_425.pkl
# Saved: train_raw_batch_426.pkl
# Saved: train_raw_batch_427.pkl
# Saved: train_raw_batch_428.pkl
# Saved: train_raw_batch_429.pkl
# Saved: train_raw_batch_430.pkl
# Saved: train_raw_batch_431.pkl
# Saved: train_raw_batch_432.pkl
# Saved: train_raw_batch_433.pkl
# Saved: train_raw_batch_434.pkl
# Saved: train_raw_batch_435.pkl
# Saved: train_raw_batch_436.pkl
# Saved: train_raw_batch_437.pkl
# Saved: train_raw_batch_438.pkl
# Saved: train_raw_batch_439.pkl
# Saved: train_raw_batch_440.pkl
# All batches processed.
# Found 0 existing batches. Starting processing...
# Saved: val_raw_batch_0.pkl
# Saved: val_raw_batch_1.pkl
# Saved: val_raw_batch_2.pkl
# Saved: val_raw_batch_3.pkl
# Saved: val_raw_batch_4.pkl
# Saved: val_raw_batch_5.pkl
# Saved: val_raw_batch_6.pkl
# Saved: val_raw_batch_7.pkl
# Saved: val_raw_batch_8.pkl
# Saved: val_raw_batch_9.pkl
# Saved: val_raw_batch_10.pkl
# Saved: val_raw_batch_11.pkl
# Saved: val_raw_batch_12.pkl
# Saved: val_raw_batch_13.pkl
# Saved: val_raw_batch_14.pkl
# Saved: val_raw_batch_15.pkl
# Saved: val_raw_batch_16.pkl
# Saved: val_raw_batch_17.pkl
# Saved: val_raw_batch_18.pkl
# Saved: val_raw_batch_19.pkl
# Saved: val_raw_batch_20.pkl
# Saved: val_raw_batch_21.pkl
# Saved: val_raw_batch_22.pkl
# Saved: val_raw_batch_23.pkl
# Saved: val_raw_batch_24.pkl
# Saved: val_raw_batch_25.pkl
# Saved: val_raw_batch_26.pkl
# Saved: val_raw_batch_27.pkl
# Saved: val_raw_batch_28.pkl
# Saved: val_raw_batch_29.pkl
# Saved: val_raw_batch_30.pkl
# Saved: val_raw_batch_31.pkl
# Saved: val_raw_batch_32.pkl
# Saved: val_raw_batch_33.pkl
# Saved: val_raw_batch_34.pkl
# Saved: val_raw_batch_35.pkl
# Saved: val_raw_batch_36.pkl
# Saved: val_raw_batch_37.pkl
# Saved: val_raw_batch_38.pkl
# Saved: val_raw_batch_39.pkl
# Saved: val_raw_batch_40.pkl
# Saved: val_raw_batch_41.pkl
# Saved: val_raw_batch_42.pkl
# Saved: val_raw_batch_43.pkl
# Saved: val_raw_batch_44.pkl
# Saved: val_raw_batch_45.pkl
# Saved: val_raw_batch_46.pkl
# Saved: val_raw_batch_47.pkl
# Saved: val_raw_batch_48.pkl
# Saved: val_raw_batch_49.pkl
# Saved: val_raw_batch_50.pkl
# Saved: val_raw_batch_51.pkl
# Saved: val_raw_batch_52.pkl
# Saved: val_raw_batch_53.pkl
# Saved: val_raw_batch_54.pkl
# Saved: val_raw_batch_55.pkl
# Saved: val_raw_batch_56.pkl
# Saved: val_raw_batch_57.pkl
# Saved: val_raw_batch_58.pkl
# Saved: val_raw_batch_59.pkl
# Saved: val_raw_batch_60.pkl
# Saved: val_raw_batch_61.pkl
# Saved: val_raw_batch_62.pkl
# Saved: val_raw_batch_63.pkl
# Saved: val_raw_batch_64.pkl
# Saved: val_raw_batch_65.pkl
# Saved: val_raw_batch_66.pkl
# Saved: val_raw_batch_67.pkl
# Saved: val_raw_batch_68.pkl
# Saved: val_raw_batch_69.pkl
# Saved: val_raw_batch_70.pkl
# Saved: val_raw_batch_71.pkl
# Saved: val_raw_batch_72.pkl
# Saved: val_raw_batch_73.pkl
# Saved: val_raw_batch_74.pkl
# Saved: val_raw_batch_75.pkl
# Saved: val_raw_batch_76.pkl
# Saved: val_raw_batch_77.pkl
# Saved: val_raw_batch_78.pkl
# Saved: val_raw_batch_79.pkl
# Saved: val_raw_batch_80.pkl
# Saved: val_raw_batch_81.pkl
# Saved: val_raw_batch_82.pkl
# Saved: val_raw_batch_83.pkl
# Saved: val_raw_batch_84.pkl
# Saved: val_raw_batch_85.pkl
# Saved: val_raw_batch_86.pkl
# Saved: val_raw_batch_87.pkl
# Saved: val_raw_batch_88.pkl
# Saved: val_raw_batch_89.pkl
# Saved: val_raw_batch_90.pkl
# Saved: val_raw_batch_91.pkl
# Saved: val_raw_batch_92.pkl
# Saved: val_raw_batch_93.pkl
# Saved: val_raw_batch_94.pkl
# Saved: val_raw_batch_95.pkl
# Saved: val_raw_batch_96.pkl
# Saved: val_raw_batch_97.pkl
# Saved: val_raw_batch_98.pkl
# Saved: val_raw_batch_99.pkl
# Saved: val_raw_batch_100.pkl
# Saved: val_raw_batch_101.pkl
# Saved: val_raw_batch_102.pkl
# Saved: val_raw_batch_103.pkl
# Saved: val_raw_batch_104.pkl
# Saved: val_raw_batch_105.pkl
# Saved: val_raw_batch_106.pkl
# Saved: val_raw_batch_107.pkl
# Saved: val_raw_batch_108.pkl
# Saved: val_raw_batch_109.pkl
# Saved: val_raw_batch_110.pkl
# All batches processed.
# Processing complete. Exiting now.

# %% [markdown]
# - An image is typically a 2D array of pixel values for grayscale images or a 3D array for RGB images (height × width × color channels). Flattening transforms this multidimensional array into a 1D array (a single row of pixel values). For example, a 100×100 RGB image (100×100×3) becomes a 1D array with 30,000 values.
#
# - Compatibility with Machine Learning Algorithms: Many traditional machine learning algorithms (e.g., Naive Bayes, Logistic Regression, SVM) require input as 1D vectors rather than 2D or 3D arrays. Flattening converts the image into a format suitable for these algorithms.

# %% [markdown]
# #### 1.3.4 Standardization (For logistic regression and SVM)

# %%
# Function to standardize (normalize) a single image using a scaler
def standardize_image(img_id, directory, scaler=None):
    img_path = os.path.join(directory, img_id + ".tif")
    img = np.array(Image.open(img_path).flatten())
    if scaler:
        img = scaler.transform([img])[0]  
    return img
# Define batch size for processing images in smaller groups    
BATCH_SIZE_STD = 250  
scaler = StandardScaler()
# Loop through the training image IDs in batches
for batch_idx in range(0, len(train_ids), BATCH_SIZE_STD):
    batch_ids = train_ids[batch_idx:batch_idx + BATCH_SIZE_STD]
    batch_data = [np.array(Image.open(os.path.join(train_dir, img_id + ".tif"))).flatten() for img_id in batch_ids]
    scaler.partial_fit(batch_data)  
    print(f"Scaler partial fit completed for batch {batch_idx // BATCH_SIZE_STD + 1}")

with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, print("Scaler fitted and saved.")

# Function to standardize images using the pre-trained scaler
def standardize_with_scaler(img_id, directory):
    img_path = os.path.join(directory, img_id + ".tif")
    img = np.array(Image.open(img_path)).flatten()
    return scaler.transform([img])[0]  
process_and_save_batches(train_ids, train_labels, train_dir, standardize_with_scaler, BATCH_SIZE_STD, "train_standardized")
process_and_save_batches(val_ids, val_labels, train_dir, standardize_with_scaler, BATCH_SIZE_STD, "val_standardized")
print("Standardization completed and standardized batches saved.")
# Out:
# Scaler partial fit completed for batch 1
# Scaler partial fit completed for batch 2
# Scaler partial fit completed for batch 3
# Scaler partial fit completed for batch 4
# Scaler partial fit completed for batch 5
# Scaler partial fit completed for batch 6
# Scaler partial fit completed for batch 7
# Scaler partial fit completed for batch 8
# Scaler partial fit completed for batch 9
# Scaler partial fit completed for batch 10
# Scaler partial fit completed for batch 11
# Scaler partial fit completed for batch 12
# Scaler partial fit completed for batch 13
# Scaler partial fit completed for batch 14
# Scaler partial fit completed for batch 15
# Scaler partial fit completed for batch 16
# Scaler partial fit completed for batch 17
# Scaler partial fit completed for batch 18
# Scaler partial fit completed for batch 19
# Scaler partial fit completed for batch 20
# Scaler partial fit completed for batch 21
# Scaler partial fit completed for batch 22
# Scaler partial fit completed for batch 23
# Scaler partial fit completed for batch 24
# Scaler partial fit completed for batch 25
# Scaler partial fit completed for batch 26
# Scaler partial fit completed for batch 27
# Scaler partial fit completed for batch 28
# Scaler partial fit completed for batch 29
# Scaler partial fit completed for batch 30
# Scaler partial fit completed for batch 31
# Scaler partial fit completed for batch 32
# Scaler partial fit completed for batch 33
# Scaler partial fit completed for batch 34
# Scaler partial fit completed for batch 35
# Scaler partial fit completed for batch 36
# Scaler partial fit completed for batch 37
# Scaler partial fit completed for batch 38
# Scaler partial fit completed for batch 39
# Scaler partial fit completed for batch 40
# Scaler partial fit completed for batch 41
# Scaler partial fit completed for batch 42
# Scaler partial fit completed for batch 43
# Scaler partial fit completed for batch 44
# Scaler partial fit completed for batch 45
# Scaler partial fit completed for batch 46
# Scaler partial fit completed for batch 47
# Scaler partial fit completed for batch 48
# Scaler partial fit completed for batch 49
# Scaler partial fit completed for batch 50
# Scaler partial fit completed for batch 51
# Scaler partial fit completed for batch 52
# Scaler partial fit completed for batch 53
# Scaler partial fit completed for batch 54
# Scaler partial fit completed for batch 55
# Scaler partial fit completed for batch 56
# Scaler partial fit completed for batch 57
# Scaler partial fit completed for batch 58
# Scaler partial fit completed for batch 59
# Scaler partial fit completed for batch 60
# Scaler partial fit completed for batch 61
# Scaler partial fit completed for batch 62
# Scaler partial fit completed for batch 63
# Scaler partial fit completed for batch 64
# Scaler partial fit completed for batch 65
# Scaler partial fit completed for batch 66
# Scaler partial fit completed for batch 67
# Scaler partial fit completed for batch 68
# Scaler partial fit completed for batch 69
# Scaler partial fit completed for batch 70
# Scaler partial fit completed for batch 71
# Scaler partial fit completed for batch 72
# Scaler partial fit completed for batch 73
# Scaler partial fit completed for batch 74
# Scaler partial fit completed for batch 75
# Scaler partial fit completed for batch 76
# Scaler partial fit completed for batch 77
# Scaler partial fit completed for batch 78
# Scaler partial fit completed for batch 79
# Scaler partial fit completed for batch 80
# Scaler partial fit completed for batch 81
# Scaler partial fit completed for batch 82
# Scaler partial fit completed for batch 83
# Scaler partial fit completed for batch 84
# Scaler partial fit completed for batch 85
# Scaler partial fit completed for batch 86
# Scaler partial fit completed for batch 87
# Scaler partial fit completed for batch 88
# Scaler partial fit completed for batch 89
# Scaler partial fit completed for batch 90
# Scaler partial fit completed for batch 91
# Scaler partial fit completed for batch 92
# Scaler partial fit completed for batch 93
# Scaler partial fit completed for batch 94
# Scaler partial fit completed for batch 95
# Scaler partial fit completed for batch 96
# Scaler partial fit completed for batch 97
# Scaler partial fit completed for batch 98
# Scaler partial fit completed for batch 99
# Scaler partial fit completed for batch 100
# Scaler partial fit completed for batch 101
# Scaler partial fit completed for batch 102
# Scaler partial fit completed for batch 103
# Scaler partial fit completed for batch 104
# Scaler partial fit completed for batch 105
# Scaler partial fit completed for batch 106
# Scaler partial fit completed for batch 107
# Scaler partial fit completed for batch 108
# Scaler partial fit completed for batch 109
# Scaler partial fit completed for batch 110
# Scaler partial fit completed for batch 111
# Scaler partial fit completed for batch 112
# Scaler partial fit completed for batch 113
# Scaler partial fit completed for batch 114
# Scaler partial fit completed for batch 115
# Scaler partial fit completed for batch 116
# Scaler partial fit completed for batch 117
# Scaler partial fit completed for batch 118
# Scaler partial fit completed for batch 119
# Scaler partial fit completed for batch 120
# Scaler partial fit completed for batch 121
# Scaler partial fit completed for batch 122
# Scaler partial fit completed for batch 123
# Scaler partial fit completed for batch 124
# Scaler partial fit completed for batch 125
# Scaler partial fit completed for batch 126
# Scaler partial fit completed for batch 127
# Scaler partial fit completed for batch 128
# Scaler partial fit completed for batch 129
# Scaler partial fit completed for batch 130
# Scaler partial fit completed for batch 131
# Scaler partial fit completed for batch 132
# Scaler partial fit completed for batch 133
# Scaler partial fit completed for batch 134
# Scaler partial fit completed for batch 135
# Scaler partial fit completed for batch 136
# Scaler partial fit completed for batch 137
# Scaler partial fit completed for batch 138
# Scaler partial fit completed for batch 139
# Scaler partial fit completed for batch 140
# Scaler partial fit completed for batch 141
# Scaler partial fit completed for batch 142
# Scaler partial fit completed for batch 143
# Scaler partial fit completed for batch 144
# Scaler partial fit completed for batch 145
# Scaler partial fit completed for batch 146
# Scaler partial fit completed for batch 147
# Scaler partial fit completed for batch 148
# Scaler partial fit completed for batch 149
# Scaler partial fit completed for batch 150
# Scaler partial fit completed for batch 151
# Scaler partial fit completed for batch 152
# Scaler partial fit completed for batch 153
# Scaler partial fit completed for batch 154
# Scaler partial fit completed for batch 155
# Scaler partial fit completed for batch 156
# Scaler partial fit completed for batch 157
# Scaler partial fit completed for batch 158
# Scaler partial fit completed for batch 159
# Scaler partial fit completed for batch 160
# Scaler partial fit completed for batch 161
# Scaler partial fit completed for batch 162
# Scaler partial fit completed for batch 163
# Scaler partial fit completed for batch 164
# Scaler partial fit completed for batch 165
# Scaler partial fit completed for batch 166
# Scaler partial fit completed for batch 167
# Scaler partial fit completed for batch 168
# Scaler partial fit completed for batch 169
# Scaler partial fit completed for batch 170
# Scaler partial fit completed for batch 171
# Scaler partial fit completed for batch 172
# Scaler partial fit completed for batch 173
# Scaler partial fit completed for batch 174
# Scaler partial fit completed for batch 175
# Scaler partial fit completed for batch 176
# Scaler partial fit completed for batch 177
# Scaler partial fit completed for batch 178
# Scaler partial fit completed for batch 179
# Scaler partial fit completed for batch 180
# Scaler partial fit completed for batch 181
# Scaler partial fit completed for batch 182
# Scaler partial fit completed for batch 183
# Scaler partial fit completed for batch 184
# Scaler partial fit completed for batch 185
# Scaler partial fit completed for batch 186
# Scaler partial fit completed for batch 187
# Scaler partial fit completed for batch 188
# Scaler partial fit completed for batch 189
# Scaler partial fit completed for batch 190
# Scaler partial fit completed for batch 191
# Scaler partial fit completed for batch 192
# Scaler partial fit completed for batch 193
# Scaler partial fit completed for batch 194
# Scaler partial fit completed for batch 195
# Scaler partial fit completed for batch 196
# Scaler partial fit completed for batch 197
# Scaler partial fit completed for batch 198
# Scaler partial fit completed for batch 199
# Scaler partial fit completed for batch 200
# Scaler partial fit completed for batch 201
# Scaler partial fit completed for batch 202
# Scaler partial fit completed for batch 203
# Scaler partial fit completed for batch 204
# Scaler partial fit completed for batch 205
# Scaler partial fit completed for batch 206
# Scaler partial fit completed for batch 207
# Scaler partial fit completed for batch 208
# Scaler partial fit completed for batch 209
# Scaler partial fit completed for batch 210
# Scaler partial fit completed for batch 211
# Scaler partial fit completed for batch 212
# Scaler partial fit completed for batch 213
# Scaler partial fit completed for batch 214
# Scaler partial fit completed for batch 215
# Scaler partial fit completed for batch 216
# Scaler partial fit completed for batch 217
# Scaler partial fit completed for batch 218
# Scaler partial fit completed for batch 219
# Scaler partial fit completed for batch 220
# Scaler partial fit completed for batch 221
# Scaler partial fit completed for batch 222
# Scaler partial fit completed for batch 223
# Scaler partial fit completed for batch 224
# Scaler partial fit completed for batch 225
# Scaler partial fit completed for batch 226
# Scaler partial fit completed for batch 227
# Scaler partial fit completed for batch 228
# Scaler partial fit completed for batch 229
# Scaler partial fit completed for batch 230
# Scaler partial fit completed for batch 231
# Scaler partial fit completed for batch 232
# Scaler partial fit completed for batch 233
# Scaler partial fit completed for batch 234
# Scaler partial fit completed for batch 235
# Scaler partial fit completed for batch 236
# Scaler partial fit completed for batch 237
# Scaler partial fit completed for batch 238
# Scaler partial fit completed for batch 239
# Scaler partial fit completed for batch 240
# Scaler partial fit completed for batch 241
# Scaler partial fit completed for batch 242
# Scaler partial fit completed for batch 243
# Scaler partial fit completed for batch 244
# Scaler partial fit completed for batch 245
# Scaler partial fit completed for batch 246
# Scaler partial fit completed for batch 247
# Scaler partial fit completed for batch 248
# Scaler partial fit completed for batch 249
# Scaler partial fit completed for batch 250
# Scaler partial fit completed for batch 251
# Scaler partial fit completed for batch 252
# Scaler partial fit completed for batch 253
# Scaler partial fit completed for batch 254
# Scaler partial fit completed for batch 255
# Scaler partial fit completed for batch 256
# Scaler partial fit completed for batch 257
# Scaler partial fit completed for batch 258
# Scaler partial fit completed for batch 259
# Scaler partial fit completed for batch 260
# Scaler partial fit completed for batch 261
# Scaler partial fit completed for batch 262
# Scaler partial fit completed for batch 263
# Scaler partial fit completed for batch 264
# Scaler partial fit completed for batch 265
# Scaler partial fit completed for batch 266
# Scaler partial fit completed for batch 267
# Scaler partial fit completed for batch 268
# Scaler partial fit completed for batch 269
# Scaler partial fit completed for batch 270
# Scaler partial fit completed for batch 271
# Scaler partial fit completed for batch 272
# Scaler partial fit completed for batch 273
# Scaler partial fit completed for batch 274
# Scaler partial fit completed for batch 275
# Scaler partial fit completed for batch 276
# Scaler partial fit completed for batch 277
# Scaler partial fit completed for batch 278
# Scaler partial fit completed for batch 279
# Scaler partial fit completed for batch 280
# Scaler partial fit completed for batch 281
# Scaler partial fit completed for batch 282
# Scaler partial fit completed for batch 283
# Scaler partial fit completed for batch 284
# Scaler partial fit completed for batch 285
# Scaler partial fit completed for batch 286
# Scaler partial fit completed for batch 287
# Scaler partial fit completed for batch 288
# Scaler partial fit completed for batch 289
# Scaler partial fit completed for batch 290
# Scaler partial fit completed for batch 291
# Scaler partial fit completed for batch 292
# Scaler partial fit completed for batch 293
# Scaler partial fit completed for batch 294
# Scaler partial fit completed for batch 295
# Scaler partial fit completed for batch 296
# Scaler partial fit completed for batch 297
# Scaler partial fit completed for batch 298
# Scaler partial fit completed for batch 299
# Scaler partial fit completed for batch 300
# Scaler partial fit completed for batch 301
# Scaler partial fit completed for batch 302
# Scaler partial fit completed for batch 303
# Scaler partial fit completed for batch 304
# Scaler partial fit completed for batch 305
# Scaler partial fit completed for batch 306
# Scaler partial fit completed for batch 307
# Scaler partial fit completed for batch 308
# Scaler partial fit completed for batch 309
# Scaler partial fit completed for batch 310
# Scaler partial fit completed for batch 311
# Scaler partial fit completed for batch 312
# Scaler partial fit completed for batch 313
# Scaler partial fit completed for batch 314
# Scaler partial fit completed for batch 315
# Scaler partial fit completed for batch 316
# Scaler partial fit completed for batch 317
# Scaler partial fit completed for batch 318
# Scaler partial fit completed for batch 319
# Scaler partial fit completed for batch 320
# Scaler partial fit completed for batch 321
# Scaler partial fit completed for batch 322
# Scaler partial fit completed for batch 323
# Scaler partial fit completed for batch 324
# Scaler partial fit completed for batch 325
# Scaler partial fit completed for batch 326
# Scaler partial fit completed for batch 327
# Scaler partial fit completed for batch 328
# Scaler partial fit completed for batch 329
# Scaler partial fit completed for batch 330
# Scaler partial fit completed for batch 331
# Scaler partial fit completed for batch 332
# Scaler partial fit completed for batch 333
# Scaler partial fit completed for batch 334
# Scaler partial fit completed for batch 335
# Scaler partial fit completed for batch 336
# Scaler partial fit completed for batch 337
# Scaler partial fit completed for batch 338
# Scaler partial fit completed for batch 339
# Scaler partial fit completed for batch 340
# Scaler partial fit completed for batch 341
# Scaler partial fit completed for batch 342
# Scaler partial fit completed for batch 343
# Scaler partial fit completed for batch 344
# Scaler partial fit completed for batch 345
# Scaler partial fit completed for batch 346
# Scaler partial fit completed for batch 347
# Scaler partial fit completed for batch 348
# Scaler partial fit completed for batch 349
# Scaler partial fit completed for batch 350
# Scaler partial fit completed for batch 351
# Scaler partial fit completed for batch 352
# Scaler partial fit completed for batch 353
# Scaler partial fit completed for batch 354
# Scaler partial fit completed for batch 355
# Scaler partial fit completed for batch 356
# Scaler partial fit completed for batch 357
# Scaler partial fit completed for batch 358
# Scaler partial fit completed for batch 359
# Scaler partial fit completed for batch 360
# Scaler partial fit completed for batch 361
# Scaler partial fit completed for batch 362
# Scaler partial fit completed for batch 363
# Scaler partial fit completed for batch 364
# Scaler partial fit completed for batch 365
# Scaler partial fit completed for batch 366
# Scaler partial fit completed for batch 367
# Scaler partial fit completed for batch 368
# Scaler partial fit completed for batch 369
# Scaler partial fit completed for batch 370
# Scaler partial fit completed for batch 371
# Scaler partial fit completed for batch 372
# Scaler partial fit completed for batch 373
# Scaler partial fit completed for batch 374
# Scaler partial fit completed for batch 375
# Scaler partial fit completed for batch 376
# Scaler partial fit completed for batch 377
# Scaler partial fit completed for batch 378
# Scaler partial fit completed for batch 379
# Scaler partial fit completed for batch 380
# Scaler partial fit completed for batch 381
# Scaler partial fit completed for batch 382
# Scaler partial fit completed for batch 383
# Scaler partial fit completed for batch 384
# Scaler partial fit completed for batch 385
# Scaler partial fit completed for batch 386
# Scaler partial fit completed for batch 387
# Scaler partial fit completed for batch 388
# Scaler partial fit completed for batch 389
# Scaler partial fit completed for batch 390
# Scaler partial fit completed for batch 391
# Scaler partial fit completed for batch 392
# Scaler partial fit completed for batch 393
# Scaler partial fit completed for batch 394
# Scaler partial fit completed for batch 395
# Scaler partial fit completed for batch 396
# Scaler partial fit completed for batch 397
# Scaler partial fit completed for batch 398
# Scaler partial fit completed for batch 399
# Scaler partial fit completed for batch 400
# Scaler partial fit completed for batch 401
# Scaler partial fit completed for batch 402
# Scaler partial fit completed for batch 403
# Scaler partial fit completed for batch 404
# Scaler partial fit completed for batch 405
# Scaler partial fit completed for batch 406
# Scaler partial fit completed for batch 407
# Scaler partial fit completed for batch 408
# Scaler partial fit completed for batch 409
# Scaler partial fit completed for batch 410
# Scaler partial fit completed for batch 411
# Scaler partial fit completed for batch 412
# Scaler partial fit completed for batch 413
# Scaler partial fit completed for batch 414
# Scaler partial fit completed for batch 415
# Scaler partial fit completed for batch 416
# Scaler partial fit completed for batch 417
# Scaler partial fit completed for batch 418
# Scaler partial fit completed for batch 419
# Scaler partial fit completed for batch 420
# Scaler partial fit completed for batch 421
# Scaler partial fit completed for batch 422
# Scaler partial fit completed for batch 423
# Scaler partial fit completed for batch 424
# Scaler partial fit completed for batch 425
# Scaler partial fit completed for batch 426
# Scaler partial fit completed for batch 427
# Scaler partial fit completed for batch 428
# Scaler partial fit completed for batch 429
# Scaler partial fit completed for batch 430
# Scaler partial fit completed for batch 431
# Scaler partial fit completed for batch 432
# Scaler partial fit completed for batch 433
# Scaler partial fit completed for batch 434
# Scaler partial fit completed for batch 435
# Scaler partial fit completed for batch 436
# Scaler partial fit completed for batch 437
# Scaler partial fit completed for batch 438
# Scaler partial fit completed for batch 439
# Scaler partial fit completed for batch 440
# Scaler partial fit completed for batch 441
# Scaler partial fit completed for batch 442
# Scaler partial fit completed for batch 443
# Scaler partial fit completed for batch 444
# Scaler partial fit completed for batch 445
# Scaler partial fit completed for batch 446
# Scaler partial fit completed for batch 447
# Scaler partial fit completed for batch 448
# Scaler partial fit completed for batch 449
# Scaler partial fit completed for batch 450
# Scaler partial fit completed for batch 451
# Scaler partial fit completed for batch 452
# Scaler partial fit completed for batch 453
# Scaler partial fit completed for batch 454
# Scaler partial fit completed for batch 455
# Scaler partial fit completed for batch 456
# Scaler partial fit completed for batch 457
# Scaler partial fit completed for batch 458
# Scaler partial fit completed for batch 459
# Scaler partial fit completed for batch 460
# Scaler partial fit completed for batch 461
# Scaler partial fit completed for batch 462
# Scaler partial fit completed for batch 463
# Scaler partial fit completed for batch 464
# Scaler partial fit completed for batch 465
# Scaler partial fit completed for batch 466
# Scaler partial fit completed for batch 467
# Scaler partial fit completed for batch 468
# Scaler partial fit completed for batch 469
# Scaler partial fit completed for batch 470
# Scaler partial fit completed for batch 471
# Scaler partial fit completed for batch 472
# Scaler partial fit completed for batch 473
# Scaler partial fit completed for batch 474
# Scaler partial fit completed for batch 475
# Scaler partial fit completed for batch 476
# Scaler partial fit completed for batch 477
# Scaler partial fit completed for batch 478
# Scaler partial fit completed for batch 479
# Scaler partial fit completed for batch 480
# Scaler partial fit completed for batch 481
# Scaler partial fit completed for batch 482
# Scaler partial fit completed for batch 483
# Scaler partial fit completed for batch 484
# Scaler partial fit completed for batch 485
# Scaler partial fit completed for batch 486
# Scaler partial fit completed for batch 487
# Scaler partial fit completed for batch 488
# Scaler partial fit completed for batch 489
# Scaler partial fit completed for batch 490
# Scaler partial fit completed for batch 491
# Scaler partial fit completed for batch 492
# Scaler partial fit completed for batch 493
# Scaler partial fit completed for batch 494
# Scaler partial fit completed for batch 495
# Scaler partial fit completed for batch 496
# Scaler partial fit completed for batch 497
# Scaler partial fit completed for batch 498
# Scaler partial fit completed for batch 499
# Scaler partial fit completed for batch 500
# Scaler partial fit completed for batch 501
# Scaler partial fit completed for batch 502
# Scaler partial fit completed for batch 503
# Scaler partial fit completed for batch 504
# Scaler partial fit completed for batch 505
# Scaler partial fit completed for batch 506
# Scaler partial fit completed for batch 507
# Scaler partial fit completed for batch 508
# Scaler partial fit completed for batch 509
# Scaler partial fit completed for batch 510
# Scaler partial fit completed for batch 511
# Scaler partial fit completed for batch 512
# Scaler partial fit completed for batch 513
# Scaler partial fit completed for batch 514
# Scaler partial fit completed for batch 515
# Scaler partial fit completed for batch 516
# Scaler partial fit completed for batch 517
# Scaler partial fit completed for batch 518
# Scaler partial fit completed for batch 519
# Scaler partial fit completed for batch 520
# Scaler partial fit completed for batch 521
# Scaler partial fit completed for batch 522
# Scaler partial fit completed for batch 523
# Scaler partial fit completed for batch 524
# Scaler partial fit completed for batch 525
# Scaler partial fit completed for batch 526
# Scaler partial fit completed for batch 527
# Scaler partial fit completed for batch 528
# Scaler partial fit completed for batch 529
# Scaler partial fit completed for batch 530
# Scaler partial fit completed for batch 531
# Scaler partial fit completed for batch 532
# Scaler partial fit completed for batch 533
# Scaler partial fit completed for batch 534
# Scaler partial fit completed for batch 535
# Scaler partial fit completed for batch 536
# Scaler partial fit completed for batch 537
# Scaler partial fit completed for batch 538
# Scaler partial fit completed for batch 539
# Scaler partial fit completed for batch 540
# Scaler partial fit completed for batch 541
# Scaler partial fit completed for batch 542
# Scaler partial fit completed for batch 543
# Scaler partial fit completed for batch 544
# Scaler partial fit completed for batch 545
# Scaler partial fit completed for batch 546
# Scaler partial fit completed for batch 547
# Scaler partial fit completed for batch 548
# Scaler partial fit completed for batch 549
# Scaler partial fit completed for batch 550
# Scaler partial fit completed for batch 551
# Scaler partial fit completed for batch 552
# Scaler partial fit completed for batch 553
# Scaler partial fit completed for batch 554
# Scaler partial fit completed for batch 555
# Scaler partial fit completed for batch 556
# Scaler partial fit completed for batch 557
# Scaler partial fit completed for batch 558
# Scaler partial fit completed for batch 559
# Scaler partial fit completed for batch 560
# Scaler partial fit completed for batch 561
# Scaler partial fit completed for batch 562
# Scaler partial fit completed for batch 563
# Scaler partial fit completed for batch 564
# Scaler partial fit completed for batch 565
# Scaler partial fit completed for batch 566
# Scaler partial fit completed for batch 567
# Scaler partial fit completed for batch 568
# Scaler partial fit completed for batch 569
# Scaler partial fit completed for batch 570
# Scaler partial fit completed for batch 571
# Scaler partial fit completed for batch 572
# Scaler partial fit completed for batch 573
# Scaler partial fit completed for batch 574
# Scaler partial fit completed for batch 575
# Scaler partial fit completed for batch 576
# Scaler partial fit completed for batch 577
# Scaler partial fit completed for batch 578
# Scaler partial fit completed for batch 579
# Scaler partial fit completed for batch 580
# Scaler partial fit completed for batch 581
# Scaler partial fit completed for batch 582
# Scaler partial fit completed for batch 583
# Scaler partial fit completed for batch 584
# Scaler partial fit completed for batch 585
# Scaler partial fit completed for batch 586
# Scaler partial fit completed for batch 587
# Scaler partial fit completed for batch 588
# Scaler partial fit completed for batch 589
# Scaler partial fit completed for batch 590
# Scaler partial fit completed for batch 591
# Scaler partial fit completed for batch 592
# Scaler partial fit completed for batch 593
# Scaler partial fit completed for batch 594
# Scaler partial fit completed for batch 595
# Scaler partial fit completed for batch 596
# Scaler partial fit completed for batch 597
# Scaler partial fit completed for batch 598
# Scaler partial fit completed for batch 599
# Scaler partial fit completed for batch 600
# Scaler partial fit completed for batch 601
# Scaler partial fit completed for batch 602
# Scaler partial fit completed for batch 603
# Scaler partial fit completed for batch 604
# Scaler partial fit completed for batch 605
# Scaler partial fit completed for batch 606
# Scaler partial fit completed for batch 607
# Scaler partial fit completed for batch 608
# Scaler partial fit completed for batch 609
# Scaler partial fit completed for batch 610
# Scaler partial fit completed for batch 611
# Scaler partial fit completed for batch 612
# Scaler partial fit completed for batch 613
# Scaler partial fit completed for batch 614
# Scaler partial fit completed for batch 615
# Scaler partial fit completed for batch 616
# Scaler partial fit completed for batch 617
# Scaler partial fit completed for batch 618
# Scaler partial fit completed for batch 619
# Scaler partial fit completed for batch 620
# Scaler partial fit completed for batch 621
# Scaler partial fit completed for batch 622
# Scaler partial fit completed for batch 623
# Scaler partial fit completed for batch 624
# Scaler partial fit completed for batch 625
# Scaler partial fit completed for batch 626
# Scaler partial fit completed for batch 627
# Scaler partial fit completed for batch 628
# Scaler partial fit completed for batch 629
# Scaler partial fit completed for batch 630
# Scaler partial fit completed for batch 631
# Scaler partial fit completed for batch 632
# Scaler partial fit completed for batch 633
# Scaler partial fit completed for batch 634
# Scaler partial fit completed for batch 635
# Scaler partial fit completed for batch 636
# Scaler partial fit completed for batch 637
# Scaler partial fit completed for batch 638
# Scaler partial fit completed for batch 639
# Scaler partial fit completed for batch 640
# Scaler partial fit completed for batch 641
# Scaler partial fit completed for batch 642
# Scaler partial fit completed for batch 643
# Scaler partial fit completed for batch 644
# Scaler partial fit completed for batch 645
# Scaler partial fit completed for batch 646
# Scaler partial fit completed for batch 647
# Scaler partial fit completed for batch 648
# Scaler partial fit completed for batch 649
# Scaler partial fit completed for batch 650
# Scaler partial fit completed for batch 651
# Scaler partial fit completed for batch 652
# Scaler partial fit completed for batch 653
# Scaler partial fit completed for batch 654
# Scaler partial fit completed for batch 655
# Scaler partial fit completed for batch 656
# Scaler partial fit completed for batch 657
# Scaler partial fit completed for batch 658
# Scaler partial fit completed for batch 659
# Scaler partial fit completed for batch 660
# Scaler partial fit completed for batch 661
# Scaler partial fit completed for batch 662
# Scaler partial fit completed for batch 663
# Scaler partial fit completed for batch 664
# Scaler partial fit completed for batch 665
# Scaler partial fit completed for batch 666
# Scaler partial fit completed for batch 667
# Scaler partial fit completed for batch 668
# Scaler partial fit completed for batch 669
# Scaler partial fit completed for batch 670
# Scaler partial fit completed for batch 671
# Scaler partial fit completed for batch 672
# Scaler partial fit completed for batch 673
# Scaler partial fit completed for batch 674
# Scaler partial fit completed for batch 675
# Scaler partial fit completed for batch 676
# Scaler partial fit completed for batch 677
# Scaler partial fit completed for batch 678
# Scaler partial fit completed for batch 679
# Scaler partial fit completed for batch 680
# Scaler partial fit completed for batch 681
# Scaler partial fit completed for batch 682
# Scaler partial fit completed for batch 683
# Scaler partial fit completed for batch 684
# Scaler partial fit completed for batch 685
# Scaler partial fit completed for batch 686
# Scaler partial fit completed for batch 687
# Scaler partial fit completed for batch 688
# Scaler partial fit completed for batch 689
# Scaler partial fit completed for batch 690
# Scaler partial fit completed for batch 691
# Scaler partial fit completed for batch 692
# Scaler partial fit completed for batch 693
# Scaler partial fit completed for batch 694
# Scaler partial fit completed for batch 695
# Scaler partial fit completed for batch 696
# Scaler partial fit completed for batch 697
# Scaler partial fit completed for batch 698
# Scaler partial fit completed for batch 699
# Scaler partial fit completed for batch 700
# Scaler partial fit completed for batch 701
# Scaler partial fit completed for batch 702
# Scaler partial fit completed for batch 703
# Scaler partial fit completed for batch 704
# Scaler partial fit completed for batch 705
# Scaler fitted and saved.
# Found 0 existing batches. Starting processing...
# Saved: train_standardized_batch_0.pkl
# Saved: train_standardized_batch_1.pkl
# Saved: train_standardized_batch_2.pkl
# Saved: train_standardized_batch_3.pkl
# Saved: train_standardized_batch_4.pkl
# Saved: train_standardized_batch_5.pkl
# Saved: train_standardized_batch_6.pkl
# Saved: train_standardized_batch_7.pkl
# Saved: train_standardized_batch_8.pkl
# Saved: train_standardized_batch_9.pkl
# Saved: train_standardized_batch_10.pkl
# Saved: train_standardized_batch_11.pkl
# Saved: train_standardized_batch_12.pkl
# Saved: train_standardized_batch_13.pkl
# Saved: train_standardized_batch_14.pkl
# Saved: train_standardized_batch_15.pkl
# Saved: train_standardized_batch_16.pkl
# Saved: train_standardized_batch_17.pkl
# Saved: train_standardized_batch_18.pkl
# Saved: train_standardized_batch_19.pkl
# Saved: train_standardized_batch_20.pkl
# Saved: train_standardized_batch_21.pkl
# Saved: train_standardized_batch_22.pkl
# Saved: train_standardized_batch_23.pkl
# Saved: train_standardized_batch_24.pkl
# Saved: train_standardized_batch_25.pkl
# Saved: train_standardized_batch_26.pkl
# Saved: train_standardized_batch_27.pkl
# Saved: train_standardized_batch_28.pkl
# Saved: train_standardized_batch_29.pkl
# Saved: train_standardized_batch_30.pkl
# Saved: train_standardized_batch_31.pkl
# Saved: train_standardized_batch_32.pkl
# Saved: train_standardized_batch_33.pkl
# Saved: train_standardized_batch_34.pkl
# Saved: train_standardized_batch_35.pkl
# Saved: train_standardized_batch_36.pkl
# Saved: train_standardized_batch_37.pkl
# Saved: train_standardized_batch_38.pkl
# Saved: train_standardized_batch_39.pkl
# Saved: train_standardized_batch_40.pkl
# Saved: train_standardized_batch_41.pkl
# Saved: train_standardized_batch_42.pkl
# Saved: train_standardized_batch_43.pkl
# Saved: train_standardized_batch_44.pkl
# Saved: train_standardized_batch_45.pkl
# Saved: train_standardized_batch_46.pkl
# Saved: train_standardized_batch_47.pkl
# Saved: train_standardized_batch_48.pkl
# Saved: train_standardized_batch_49.pkl
# Saved: train_standardized_batch_50.pkl
# Saved: train_standardized_batch_51.pkl
# Saved: train_standardized_batch_52.pkl
# Saved: train_standardized_batch_53.pkl
# Saved: train_standardized_batch_54.pkl
# Saved: train_standardized_batch_55.pkl
# Saved: train_standardized_batch_56.pkl
# Saved: train_standardized_batch_57.pkl
# Saved: train_standardized_batch_58.pkl
# Saved: train_standardized_batch_59.pkl
# Saved: train_standardized_batch_60.pkl
# Saved: train_standardized_batch_61.pkl
# Saved: train_standardized_batch_62.pkl
# Saved: train_standardized_batch_63.pkl
# Saved: train_standardized_batch_64.pkl
# Saved: train_standardized_batch_65.pkl
# Saved: train_standardized_batch_66.pkl
# Saved: train_standardized_batch_67.pkl
# Saved: train_standardized_batch_68.pkl
# Saved: train_standardized_batch_69.pkl
# Saved: train_standardized_batch_70.pkl
# Saved: train_standardized_batch_71.pkl
# Saved: train_standardized_batch_72.pkl
# Saved: train_standardized_batch_73.pkl
# Saved: train_standardized_batch_74.pkl
# Saved: train_standardized_batch_75.pkl
# Saved: train_standardized_batch_76.pkl
# Saved: train_standardized_batch_77.pkl
# Saved: train_standardized_batch_78.pkl
# Saved: train_standardized_batch_79.pkl
# Saved: train_standardized_batch_80.pkl
# Saved: train_standardized_batch_81.pkl
# Saved: train_standardized_batch_82.pkl
# Saved: train_standardized_batch_83.pkl
# Saved: train_standardized_batch_84.pkl
# Saved: train_standardized_batch_85.pkl
# Saved: train_standardized_batch_86.pkl
# Saved: train_standardized_batch_87.pkl
# Saved: train_standardized_batch_88.pkl
# Saved: train_standardized_batch_89.pkl
# Saved: train_standardized_batch_90.pkl
# Saved: train_standardized_batch_91.pkl
# Saved: train_standardized_batch_92.pkl
# Saved: train_standardized_batch_93.pkl
# Saved: train_standardized_batch_94.pkl
# Saved: train_standardized_batch_95.pkl
# Saved: train_standardized_batch_96.pkl
# Saved: train_standardized_batch_97.pkl
# Saved: train_standardized_batch_98.pkl
# Saved: train_standardized_batch_99.pkl
# Saved: train_standardized_batch_100.pkl
# Saved: train_standardized_batch_101.pkl
# Saved: train_standardized_batch_102.pkl
# Saved: train_standardized_batch_103.pkl
# Saved: train_standardized_batch_104.pkl
# Saved: train_standardized_batch_105.pkl
# Saved: train_standardized_batch_106.pkl
# Saved: train_standardized_batch_107.pkl
# Saved: train_standardized_batch_108.pkl
# Saved: train_standardized_batch_109.pkl
# Saved: train_standardized_batch_110.pkl
# Saved: train_standardized_batch_111.pkl
# Saved: train_standardized_batch_112.pkl
# Saved: train_standardized_batch_113.pkl
# Saved: train_standardized_batch_114.pkl
# Saved: train_standardized_batch_115.pkl
# Saved: train_standardized_batch_116.pkl
# Saved: train_standardized_batch_117.pkl
# Saved: train_standardized_batch_118.pkl
# Saved: train_standardized_batch_119.pkl
# Saved: train_standardized_batch_120.pkl
# Saved: train_standardized_batch_121.pkl
# Saved: train_standardized_batch_122.pkl
# Saved: train_standardized_batch_123.pkl
# Saved: train_standardized_batch_124.pkl
# Saved: train_standardized_batch_125.pkl
# Saved: train_standardized_batch_126.pkl
# Saved: train_standardized_batch_127.pkl
# Saved: train_standardized_batch_128.pkl
# Saved: train_standardized_batch_129.pkl
# Saved: train_standardized_batch_130.pkl
# Saved: train_standardized_batch_131.pkl
# Saved: train_standardized_batch_132.pkl
# Saved: train_standardized_batch_133.pkl
# Saved: train_standardized_batch_134.pkl
# Saved: train_standardized_batch_135.pkl
# Saved: train_standardized_batch_136.pkl
# Saved: train_standardized_batch_137.pkl
# Saved: train_standardized_batch_138.pkl
# Saved: train_standardized_batch_139.pkl
# Saved: train_standardized_batch_140.pkl
# Saved: train_standardized_batch_141.pkl
# Saved: train_standardized_batch_142.pkl
# Saved: train_standardized_batch_143.pkl
# Saved: train_standardized_batch_144.pkl
# Saved: train_standardized_batch_145.pkl
# Saved: train_standardized_batch_146.pkl
# Saved: train_standardized_batch_147.pkl
# Saved: train_standardized_batch_148.pkl
# Saved: train_standardized_batch_149.pkl
# Saved: train_standardized_batch_150.pkl
# Saved: train_standardized_batch_151.pkl
# Saved: train_standardized_batch_152.pkl
# Saved: train_standardized_batch_153.pkl
# Saved: train_standardized_batch_154.pkl
# Saved: train_standardized_batch_155.pkl
# Saved: train_standardized_batch_156.pkl
# Saved: train_standardized_batch_157.pkl
# Saved: train_standardized_batch_158.pkl
# Saved: train_standardized_batch_159.pkl
# Saved: train_standardized_batch_160.pkl
# Saved: train_standardized_batch_161.pkl
# Saved: train_standardized_batch_162.pkl
# Saved: train_standardized_batch_163.pkl
# Saved: train_standardized_batch_164.pkl
# Saved: train_standardized_batch_165.pkl
# Saved: train_standardized_batch_166.pkl
# Saved: train_standardized_batch_167.pkl
# Saved: train_standardized_batch_168.pkl
# Saved: train_standardized_batch_169.pkl
# Saved: train_standardized_batch_170.pkl
# Saved: train_standardized_batch_171.pkl
# Saved: train_standardized_batch_172.pkl
# Saved: train_standardized_batch_173.pkl
# Saved: train_standardized_batch_174.pkl
# Saved: train_standardized_batch_175.pkl
# Saved: train_standardized_batch_176.pkl
# Saved: train_standardized_batch_177.pkl
# Saved: train_standardized_batch_178.pkl
# Saved: train_standardized_batch_179.pkl
# Saved: train_standardized_batch_180.pkl
# Saved: train_standardized_batch_181.pkl
# Saved: train_standardized_batch_182.pkl
# Saved: train_standardized_batch_183.pkl
# Saved: train_standardized_batch_184.pkl
# Saved: train_standardized_batch_185.pkl
# Saved: train_standardized_batch_186.pkl
# Saved: train_standardized_batch_187.pkl
# Saved: train_standardized_batch_188.pkl
# Saved: train_standardized_batch_189.pkl
# Saved: train_standardized_batch_190.pkl
# Saved: train_standardized_batch_191.pkl
# Saved: train_standardized_batch_192.pkl
# Saved: train_standardized_batch_193.pkl
# Saved: train_standardized_batch_194.pkl
# Saved: train_standardized_batch_195.pkl
# Saved: train_standardized_batch_196.pkl
# Saved: train_standardized_batch_197.pkl
# Saved: train_standardized_batch_198.pkl
# Saved: train_standardized_batch_199.pkl
# Saved: train_standardized_batch_200.pkl
# Saved: train_standardized_batch_201.pkl
# Saved: train_standardized_batch_202.pkl
# Saved: train_standardized_batch_203.pkl
# Saved: train_standardized_batch_204.pkl
# Saved: train_standardized_batch_205.pkl
# Saved: train_standardized_batch_206.pkl
# Saved: train_standardized_batch_207.pkl
# Saved: train_standardized_batch_208.pkl
# Saved: train_standardized_batch_209.pkl
# Saved: train_standardized_batch_210.pkl
# Saved: train_standardized_batch_211.pkl
# Saved: train_standardized_batch_212.pkl
# Saved: train_standardized_batch_213.pkl
# Saved: train_standardized_batch_214.pkl
# Saved: train_standardized_batch_215.pkl
# Saved: train_standardized_batch_216.pkl
# Saved: train_standardized_batch_217.pkl
# Saved: train_standardized_batch_218.pkl
# Saved: train_standardized_batch_219.pkl
# Saved: train_standardized_batch_220.pkl
# Saved: train_standardized_batch_221.pkl
# Saved: train_standardized_batch_222.pkl
# Saved: train_standardized_batch_223.pkl
# Saved: train_standardized_batch_224.pkl
# Saved: train_standardized_batch_225.pkl
# Saved: train_standardized_batch_226.pkl
# Saved: train_standardized_batch_227.pkl
# Saved: train_standardized_batch_228.pkl
# Saved: train_standardized_batch_229.pkl
# Saved: train_standardized_batch_230.pkl
# Saved: train_standardized_batch_231.pkl
# Saved: train_standardized_batch_232.pkl
# Saved: train_standardized_batch_233.pkl
# Saved: train_standardized_batch_234.pkl
# Saved: train_standardized_batch_235.pkl
# Saved: train_standardized_batch_236.pkl
# Saved: train_standardized_batch_237.pkl
# Saved: train_standardized_batch_238.pkl
# Saved: train_standardized_batch_239.pkl
# Saved: train_standardized_batch_240.pkl
# Saved: train_standardized_batch_241.pkl
# Saved: train_standardized_batch_242.pkl
# Saved: train_standardized_batch_243.pkl
# Saved: train_standardized_batch_244.pkl
# Saved: train_standardized_batch_245.pkl
# Saved: train_standardized_batch_246.pkl
# Saved: train_standardized_batch_247.pkl
# Saved: train_standardized_batch_248.pkl
# Saved: train_standardized_batch_249.pkl
# Saved: train_standardized_batch_250.pkl
# Saved: train_standardized_batch_251.pkl
# Saved: train_standardized_batch_252.pkl
# Saved: train_standardized_batch_253.pkl
# Saved: train_standardized_batch_254.pkl
# Saved: train_standardized_batch_255.pkl
# Saved: train_standardized_batch_256.pkl
# Saved: train_standardized_batch_257.pkl
# Saved: train_standardized_batch_258.pkl
# Saved: train_standardized_batch_259.pkl
# Saved: train_standardized_batch_260.pkl
# Saved: train_standardized_batch_261.pkl
# Saved: train_standardized_batch_262.pkl
# Saved: train_standardized_batch_263.pkl
# Saved: train_standardized_batch_264.pkl
# Saved: train_standardized_batch_265.pkl
# Saved: train_standardized_batch_266.pkl
# Saved: train_standardized_batch_267.pkl
# Saved: train_standardized_batch_268.pkl
# Saved: train_standardized_batch_269.pkl
# Saved: train_standardized_batch_270.pkl
# Saved: train_standardized_batch_271.pkl
# Saved: train_standardized_batch_272.pkl
# Saved: train_standardized_batch_273.pkl
# Saved: train_standardized_batch_274.pkl
# Saved: train_standardized_batch_275.pkl
# Saved: train_standardized_batch_276.pkl
# Saved: train_standardized_batch_277.pkl
# Saved: train_standardized_batch_278.pkl
# Saved: train_standardized_batch_279.pkl
# Saved: train_standardized_batch_280.pkl
# Saved: train_standardized_batch_281.pkl
# Saved: train_standardized_batch_282.pkl
# Saved: train_standardized_batch_283.pkl
# Saved: train_standardized_batch_284.pkl
# Saved: train_standardized_batch_285.pkl
# Saved: train_standardized_batch_286.pkl
# Saved: train_standardized_batch_287.pkl
# Saved: train_standardized_batch_288.pkl
# Saved: train_standardized_batch_289.pkl
# Saved: train_standardized_batch_290.pkl
# Saved: train_standardized_batch_291.pkl
# Saved: train_standardized_batch_292.pkl
# Saved: train_standardized_batch_293.pkl
# Saved: train_standardized_batch_294.pkl
# Saved: train_standardized_batch_295.pkl
# Saved: train_standardized_batch_296.pkl
# Saved: train_standardized_batch_297.pkl
# Saved: train_standardized_batch_298.pkl
# Saved: train_standardized_batch_299.pkl
# Saved: train_standardized_batch_300.pkl
# Saved: train_standardized_batch_301.pkl
# Saved: train_standardized_batch_302.pkl
# Saved: train_standardized_batch_303.pkl
# Saved: train_standardized_batch_304.pkl
# Saved: train_standardized_batch_305.pkl
# Saved: train_standardized_batch_306.pkl
# Saved: train_standardized_batch_307.pkl
# Saved: train_standardized_batch_308.pkl
# Saved: train_standardized_batch_309.pkl
# Saved: train_standardized_batch_310.pkl
# Saved: train_standardized_batch_311.pkl
# Saved: train_standardized_batch_312.pkl
# Saved: train_standardized_batch_313.pkl
# Saved: train_standardized_batch_314.pkl
# Saved: train_standardized_batch_315.pkl
# Saved: train_standardized_batch_316.pkl
# Saved: train_standardized_batch_317.pkl
# Saved: train_standardized_batch_318.pkl
# Saved: train_standardized_batch_319.pkl
# Saved: train_standardized_batch_320.pkl
# Saved: train_standardized_batch_321.pkl
# Saved: train_standardized_batch_322.pkl
# Saved: train_standardized_batch_323.pkl
# Saved: train_standardized_batch_324.pkl
# Saved: train_standardized_batch_325.pkl
# Saved: train_standardized_batch_326.pkl
# Saved: train_standardized_batch_327.pkl
# Saved: train_standardized_batch_328.pkl
# Saved: train_standardized_batch_329.pkl
# Saved: train_standardized_batch_330.pkl
# Saved: train_standardized_batch_331.pkl
# Saved: train_standardized_batch_332.pkl
# Saved: train_standardized_batch_333.pkl
# Saved: train_standardized_batch_334.pkl
# Saved: train_standardized_batch_335.pkl
# Saved: train_standardized_batch_336.pkl
# Saved: train_standardized_batch_337.pkl
# Saved: train_standardized_batch_338.pkl
# Saved: train_standardized_batch_339.pkl
# Saved: train_standardized_batch_340.pkl
# Saved: train_standardized_batch_341.pkl
# Saved: train_standardized_batch_342.pkl
# Saved: train_standardized_batch_343.pkl
# Saved: train_standardized_batch_344.pkl
# Saved: train_standardized_batch_345.pkl
# Saved: train_standardized_batch_346.pkl
# Saved: train_standardized_batch_347.pkl
# Saved: train_standardized_batch_348.pkl
# Saved: train_standardized_batch_349.pkl
# Saved: train_standardized_batch_350.pkl
# Saved: train_standardized_batch_351.pkl
# Saved: train_standardized_batch_352.pkl
# Saved: train_standardized_batch_353.pkl
# Saved: train_standardized_batch_354.pkl
# Saved: train_standardized_batch_355.pkl
# Saved: train_standardized_batch_356.pkl
# Saved: train_standardized_batch_357.pkl
# Saved: train_standardized_batch_358.pkl
# Saved: train_standardized_batch_359.pkl
# Saved: train_standardized_batch_360.pkl
# Saved: train_standardized_batch_361.pkl
# Saved: train_standardized_batch_362.pkl
# Saved: train_standardized_batch_363.pkl
# Saved: train_standardized_batch_364.pkl
# Saved: train_standardized_batch_365.pkl
# Saved: train_standardized_batch_366.pkl
# Saved: train_standardized_batch_367.pkl
# Saved: train_standardized_batch_368.pkl
# Saved: train_standardized_batch_369.pkl
# Saved: train_standardized_batch_370.pkl
# Saved: train_standardized_batch_371.pkl
# Saved: train_standardized_batch_372.pkl
# Saved: train_standardized_batch_373.pkl
# Saved: train_standardized_batch_374.pkl
# Saved: train_standardized_batch_375.pkl
# Saved: train_standardized_batch_376.pkl
# Saved: train_standardized_batch_377.pkl
# Saved: train_standardized_batch_378.pkl
# Saved: train_standardized_batch_379.pkl
# Saved: train_standardized_batch_380.pkl
# Saved: train_standardized_batch_381.pkl
# Saved: train_standardized_batch_382.pkl
# Saved: train_standardized_batch_383.pkl
# Saved: train_standardized_batch_384.pkl
# Saved: train_standardized_batch_385.pkl
# Saved: train_standardized_batch_386.pkl
# Saved: train_standardized_batch_387.pkl
# Saved: train_standardized_batch_388.pkl
# Saved: train_standardized_batch_389.pkl
# Saved: train_standardized_batch_390.pkl
# Saved: train_standardized_batch_391.pkl
# Saved: train_standardized_batch_392.pkl
# Saved: train_standardized_batch_393.pkl
# Saved: train_standardized_batch_394.pkl
# Saved: train_standardized_batch_395.pkl
# Saved: train_standardized_batch_396.pkl
# Saved: train_standardized_batch_397.pkl
# Saved: train_standardized_batch_398.pkl
# Saved: train_standardized_batch_399.pkl
# Saved: train_standardized_batch_400.pkl
# Saved: train_standardized_batch_401.pkl
# Saved: train_standardized_batch_402.pkl
# Saved: train_standardized_batch_403.pkl
# Saved: train_standardized_batch_404.pkl
# Saved: train_standardized_batch_405.pkl
# Saved: train_standardized_batch_406.pkl
# Saved: train_standardized_batch_407.pkl
# Saved: train_standardized_batch_408.pkl
# Saved: train_standardized_batch_409.pkl
# Saved: train_standardized_batch_410.pkl
# Saved: train_standardized_batch_411.pkl
# Saved: train_standardized_batch_412.pkl
# Saved: train_standardized_batch_413.pkl
# Saved: train_standardized_batch_414.pkl
# Saved: train_standardized_batch_415.pkl
# Saved: train_standardized_batch_416.pkl
# Saved: train_standardized_batch_417.pkl
# Saved: train_standardized_batch_418.pkl
# Saved: train_standardized_batch_419.pkl
# Saved: train_standardized_batch_420.pkl
# Saved: train_standardized_batch_421.pkl
# Saved: train_standardized_batch_422.pkl
# Saved: train_standardized_batch_423.pkl
# Saved: train_standardized_batch_424.pkl
# Saved: train_standardized_batch_425.pkl
# Saved: train_standardized_batch_426.pkl
# Saved: train_standardized_batch_427.pkl
# Saved: train_standardized_batch_428.pkl
# Saved: train_standardized_batch_429.pkl
# Saved: train_standardized_batch_430.pkl
# Saved: train_standardized_batch_431.pkl
# Saved: train_standardized_batch_432.pkl
# Saved: train_standardized_batch_433.pkl
# Saved: train_standardized_batch_434.pkl
# Saved: train_standardized_batch_435.pkl
# Saved: train_standardized_batch_436.pkl
# Saved: train_standardized_batch_437.pkl
# Saved: train_standardized_batch_438.pkl
# Saved: train_standardized_batch_439.pkl
# Saved: train_standardized_batch_440.pkl
# Saved: train_standardized_batch_441.pkl
# Saved: train_standardized_batch_442.pkl
# Saved: train_standardized_batch_443.pkl
# Saved: train_standardized_batch_444.pkl
# ...
# Saved: train_standardized_batch_475.pkl
# Saved: train_standardized_batch_476.pkl
# Saved: train_standardized_batch_477.pkl
# Saved: train_standardized_batch_478.pkl
# Saved: train_standardized_batch_479.pkl
# Saved: train_standardized_batch_480.pkl
# Saved: train_standardized_batch_481.pkl
# Saved: train_standardized_batch_482.pkl
# Saved: train_standardized_batch_483.pkl
# Saved: train_standardized_batch_484.pkl
# Saved: train_standardized_batch_485.pkl
# Saved: train_standardized_batch_486.pkl
# Saved: train_standardized_batch_487.pkl
# Saved: train_standardized_batch_488.pkl
# Saved: train_standardized_batch_489.pkl
# Saved: train_standardized_batch_490.pkl
# Saved: train_standardized_batch_491.pkl
# Saved: train_standardized_batch_492.pkl
# Saved: train_standardized_batch_493.pkl
# Saved: train_standardized_batch_494.pkl
# Saved: train_standardized_batch_495.pkl
# Saved: train_standardized_batch_496.pkl
# Saved: train_standardized_batch_497.pkl
# Saved: train_standardized_batch_498.pkl
# Saved: train_standardized_batch_499.pkl
# Saved: train_standardized_batch_500.pkl
# Saved: train_standardized_batch_501.pkl
# Saved: train_standardized_batch_502.pkl
# Saved: train_standardized_batch_503.pkl
# Saved: train_standardized_batch_504.pkl
# Saved: train_standardized_batch_505.pkl
# Saved: train_standardized_batch_506.pkl
# Saved: train_standardized_batch_507.pkl
# Saved: train_standardized_batch_508.pkl
# Saved: train_standardized_batch_509.pkl
# Saved: train_standardized_batch_510.pkl
# Saved: train_standardized_batch_511.pkl
# Saved: train_standardized_batch_512.pkl
# Saved: train_standardized_batch_513.pkl
# Saved: train_standardized_batch_514.pkl
# Saved: train_standardized_batch_515.pkl
# Saved: train_standardized_batch_516.pkl
# Saved: train_standardized_batch_517.pkl
# Saved: train_standardized_batch_518.pkl
# Saved: train_standardized_batch_519.pkl
# Saved: train_standardized_batch_520.pkl
# Saved: train_standardized_batch_521.pkl
# Saved: train_standardized_batch_522.pkl
# Saved: train_standardized_batch_523.pkl
# Saved: train_standardized_batch_524.pkl
# Saved: train_standardized_batch_525.pkl
# Saved: train_standardized_batch_526.pkl
# Saved: train_standardized_batch_527.pkl
# Saved: train_standardized_batch_528.pkl
# Saved: train_standardized_batch_529.pkl
# Saved: train_standardized_batch_530.pkl
# Saved: train_standardized_batch_531.pkl
# Saved: train_standardized_batch_532.pkl
# Saved: train_standardized_batch_533.pkl
# Saved: train_standardized_batch_534.pkl
# Saved: train_standardized_batch_535.pkl
# Saved: train_standardized_batch_536.pkl
# Saved: train_standardized_batch_537.pkl
# Saved: train_standardized_batch_538.pkl
# Saved: train_standardized_batch_539.pkl
# Saved: train_standardized_batch_540.pkl
# Saved: train_standardized_batch_541.pkl
# Saved: train_standardized_batch_542.pkl
# Saved: train_standardized_batch_543.pkl
# Saved: train_standardized_batch_544.pkl
# Saved: train_standardized_batch_545.pkl
# Saved: train_standardized_batch_546.pkl
# Saved: train_standardized_batch_547.pkl
# Saved: train_standardized_batch_548.pkl
# Saved: train_standardized_batch_549.pkl
# Saved: train_standardized_batch_550.pkl
# Saved: train_standardized_batch_551.pkl
# Saved: train_standardized_batch_552.pkl
# Saved: train_standardized_batch_553.pkl
# Saved: train_standardized_batch_554.pkl
# Saved: train_standardized_batch_555.pkl
# Saved: train_standardized_batch_556.pkl
# Saved: train_standardized_batch_557.pkl
# Saved: train_standardized_batch_558.pkl
# Saved: train_standardized_batch_559.pkl
# Saved: train_standardized_batch_560.pkl
# Saved: train_standardized_batch_561.pkl
# Saved: train_standardized_batch_562.pkl
# Saved: train_standardized_batch_563.pkl
# Saved: train_standardized_batch_564.pkl
# Saved: train_standardized_batch_565.pkl
# Saved: train_standardized_batch_566.pkl
# Saved: train_standardized_batch_567.pkl
# Saved: train_standardized_batch_568.pkl
# Saved: train_standardized_batch_569.pkl
# Saved: train_standardized_batch_570.pkl
# Saved: train_standardized_batch_571.pkl
# Saved: train_standardized_batch_572.pkl
# Saved: train_standardized_batch_573.pkl
# Saved: train_standardized_batch_574.pkl
# Saved: train_standardized_batch_575.pkl
# Saved: train_standardized_batch_576.pkl
# Saved: train_standardized_batch_577.pkl
# Saved: train_standardized_batch_578.pkl
# Saved: train_standardized_batch_579.pkl
# Saved: train_standardized_batch_580.pkl
# Saved: train_standardized_batch_581.pkl
# Saved: train_standardized_batch_582.pkl
# Saved: train_standardized_batch_583.pkl
# Saved: train_standardized_batch_584.pkl
# Saved: train_standardized_batch_585.pkl
# Saved: train_standardized_batch_586.pkl
# Saved: train_standardized_batch_587.pkl
# Saved: train_standardized_batch_588.pkl
# Saved: train_standardized_batch_589.pkl
# Saved: train_standardized_batch_590.pkl
# Saved: train_standardized_batch_591.pkl
# Saved: train_standardized_batch_592.pkl
# Saved: train_standardized_batch_593.pkl
# Saved: train_standardized_batch_594.pkl
# Saved: train_standardized_batch_595.pkl
# Saved: train_standardized_batch_596.pkl
# Saved: train_standardized_batch_597.pkl
# Saved: train_standardized_batch_598.pkl
# Saved: train_standardized_batch_599.pkl
# Saved: train_standardized_batch_600.pkl
# Saved: train_standardized_batch_601.pkl
# Saved: train_standardized_batch_602.pkl
# Saved: train_standardized_batch_603.pkl
# Saved: train_standardized_batch_604.pkl
# Saved: train_standardized_batch_605.pkl
# Saved: train_standardized_batch_606.pkl
# Saved: train_standardized_batch_607.pkl
# Saved: train_standardized_batch_608.pkl
# Saved: train_standardized_batch_609.pkl
# Saved: train_standardized_batch_610.pkl
# Saved: train_standardized_batch_611.pkl
# Saved: train_standardized_batch_612.pkl
# Saved: train_standardized_batch_613.pkl
# Saved: train_standardized_batch_614.pkl
# Saved: train_standardized_batch_615.pkl
# Saved: train_standardized_batch_616.pkl
# Saved: train_standardized_batch_617.pkl
# Saved: train_standardized_batch_618.pkl
# Saved: train_standardized_batch_619.pkl
# Saved: train_standardized_batch_620.pkl
# Saved: train_standardized_batch_621.pkl
# Saved: train_standardized_batch_622.pkl
# Saved: train_standardized_batch_623.pkl
# Saved: train_standardized_batch_624.pkl
# Saved: train_standardized_batch_625.pkl
# Saved: train_standardized_batch_626.pkl
# Saved: train_standardized_batch_627.pkl
# Saved: train_standardized_batch_628.pkl
# Saved: train_standardized_batch_629.pkl
# Saved: train_standardized_batch_630.pkl
# Saved: train_standardized_batch_631.pkl
# Saved: train_standardized_batch_632.pkl
# Saved: train_standardized_batch_633.pkl
# Saved: train_standardized_batch_634.pkl
# Saved: train_standardized_batch_635.pkl
# Saved: train_standardized_batch_636.pkl
# Saved: train_standardized_batch_637.pkl
# Saved: train_standardized_batch_638.pkl
# Saved: train_standardized_batch_639.pkl
# Saved: train_standardized_batch_640.pkl
# Saved: train_standardized_batch_641.pkl
# Saved: train_standardized_batch_642.pkl
# Saved: train_standardized_batch_643.pkl
# Saved: train_standardized_batch_644.pkl
# Saved: train_standardized_batch_645.pkl
# Saved: train_standardized_batch_646.pkl
# Saved: train_standardized_batch_647.pkl
# Saved: train_standardized_batch_648.pkl
# Saved: train_standardized_batch_649.pkl
# Saved: train_standardized_batch_650.pkl
# Saved: train_standardized_batch_651.pkl
# Saved: train_standardized_batch_652.pkl
# Saved: train_standardized_batch_653.pkl
# Saved: train_standardized_batch_654.pkl
# Saved: train_standardized_batch_655.pkl
# Saved: train_standardized_batch_656.pkl
# Saved: train_standardized_batch_657.pkl
# Saved: train_standardized_batch_658.pkl
# Saved: train_standardized_batch_659.pkl
# Saved: train_standardized_batch_660.pkl
# Saved: train_standardized_batch_661.pkl
# Saved: train_standardized_batch_662.pkl
# Saved: train_standardized_batch_663.pkl
# Saved: train_standardized_batch_664.pkl
# Saved: train_standardized_batch_665.pkl
# Saved: train_standardized_batch_666.pkl
# Saved: train_standardized_batch_667.pkl
# Saved: train_standardized_batch_668.pkl
# Saved: train_standardized_batch_669.pkl
# Saved: train_standardized_batch_670.pkl
# Saved: train_standardized_batch_671.pkl
# Saved: train_standardized_batch_672.pkl
# Saved: train_standardized_batch_673.pkl
# Saved: train_standardized_batch_674.pkl
# Saved: train_standardized_batch_675.pkl
# Saved: train_standardized_batch_676.pkl
# Saved: train_standardized_batch_677.pkl
# Saved: train_standardized_batch_678.pkl
# Saved: train_standardized_batch_679.pkl
# Saved: train_standardized_batch_680.pkl
# Saved: train_standardized_batch_681.pkl
# Saved: train_standardized_batch_682.pkl
# Saved: train_standardized_batch_683.pkl
# Saved: train_standardized_batch_684.pkl
# Saved: train_standardized_batch_685.pkl
# Saved: train_standardized_batch_686.pkl
# Saved: train_standardized_batch_687.pkl
# Saved: train_standardized_batch_688.pkl
# Saved: train_standardized_batch_689.pkl
# Saved: train_standardized_batch_690.pkl
# Saved: train_standardized_batch_691.pkl
# Saved: train_standardized_batch_692.pkl
# Saved: train_standardized_batch_693.pkl
# Saved: train_standardized_batch_694.pkl
# Saved: train_standardized_batch_695.pkl
# Saved: train_standardized_batch_696.pkl
# Saved: train_standardized_batch_697.pkl
# Saved: train_standardized_batch_698.pkl
# Saved: train_standardized_batch_699.pkl
# Saved: train_standardized_batch_700.pkl
# Saved: train_standardized_batch_701.pkl
# Saved: train_standardized_batch_702.pkl
# Saved: train_standardized_batch_703.pkl
# Saved: train_standardized_batch_704.pkl
# All batches processed.
# Found 0 existing batches. Starting processing...
# Saved: val_standardized_batch_0.pkl
# Saved: val_standardized_batch_1.pkl
# Saved: val_standardized_batch_2.pkl
# Saved: val_standardized_batch_3.pkl
# Saved: val_standardized_batch_4.pkl
# Saved: val_standardized_batch_5.pkl
# Saved: val_standardized_batch_6.pkl
# Saved: val_standardized_batch_7.pkl
# Saved: val_standardized_batch_8.pkl
# Saved: val_standardized_batch_9.pkl
# Saved: val_standardized_batch_10.pkl
# Saved: val_standardized_batch_11.pkl
# Saved: val_standardized_batch_12.pkl
# Saved: val_standardized_batch_13.pkl
# Saved: val_standardized_batch_14.pkl
# Saved: val_standardized_batch_15.pkl
# Saved: val_standardized_batch_16.pkl
# Saved: val_standardized_batch_17.pkl
# Saved: val_standardized_batch_18.pkl
# Saved: val_standardized_batch_19.pkl
# Saved: val_standardized_batch_20.pkl
# Saved: val_standardized_batch_21.pkl
# Saved: val_standardized_batch_22.pkl
# Saved: val_standardized_batch_23.pkl
# Saved: val_standardized_batch_24.pkl
# Saved: val_standardized_batch_25.pkl
# Saved: val_standardized_batch_26.pkl
# Saved: val_standardized_batch_27.pkl
# Saved: val_standardized_batch_28.pkl
# Saved: val_standardized_batch_29.pkl
# Saved: val_standardized_batch_30.pkl
# Saved: val_standardized_batch_31.pkl
# Saved: val_standardized_batch_32.pkl
# Saved: val_standardized_batch_33.pkl
# Saved: val_standardized_batch_34.pkl
# Saved: val_standardized_batch_35.pkl
# Saved: val_standardized_batch_36.pkl
# Saved: val_standardized_batch_37.pkl
# Saved: val_standardized_batch_38.pkl
# Saved: val_standardized_batch_39.pkl
# Saved: val_standardized_batch_40.pkl
# Saved: val_standardized_batch_41.pkl
# Saved: val_standardized_batch_42.pkl
# Saved: val_standardized_batch_43.pkl
# Saved: val_standardized_batch_44.pkl
# Saved: val_standardized_batch_45.pkl
# Saved: val_standardized_batch_46.pkl
# Saved: val_standardized_batch_47.pkl
# Saved: val_standardized_batch_48.pkl
# Saved: val_standardized_batch_49.pkl
# Saved: val_standardized_batch_50.pkl
# Saved: val_standardized_batch_51.pkl
# Saved: val_standardized_batch_52.pkl
# Saved: val_standardized_batch_53.pkl
# Saved: val_standardized_batch_54.pkl
# Saved: val_standardized_batch_55.pkl
# Saved: val_standardized_batch_56.pkl
# Saved: val_standardized_batch_57.pkl
# Saved: val_standardized_batch_58.pkl
# Saved: val_standardized_batch_59.pkl
# Saved: val_standardized_batch_60.pkl
# Saved: val_standardized_batch_61.pkl
# Saved: val_standardized_batch_62.pkl
# Saved: val_standardized_batch_63.pkl
# Saved: val_standardized_batch_64.pkl
# Saved: val_standardized_batch_65.pkl
# Saved: val_standardized_batch_66.pkl
# Saved: val_standardized_batch_67.pkl
# Saved: val_standardized_batch_68.pkl
# Saved: val_standardized_batch_69.pkl
# Saved: val_standardized_batch_70.pkl
# Saved: val_standardized_batch_71.pkl
# Saved: val_standardized_batch_72.pkl
# Saved: val_standardized_batch_73.pkl
# Saved: val_standardized_batch_74.pkl
# Saved: val_standardized_batch_75.pkl
# Saved: val_standardized_batch_76.pkl
# Saved: val_standardized_batch_77.pkl
# Saved: val_standardized_batch_78.pkl
# Saved: val_standardized_batch_79.pkl
# Saved: val_standardized_batch_80.pkl
# Saved: val_standardized_batch_81.pkl
# Saved: val_standardized_batch_82.pkl
# Saved: val_standardized_batch_83.pkl
# Saved: val_standardized_batch_84.pkl
# Saved: val_standardized_batch_85.pkl
# Saved: val_standardized_batch_86.pkl
# Saved: val_standardized_batch_87.pkl
# Saved: val_standardized_batch_88.pkl
# Saved: val_standardized_batch_89.pkl
# Saved: val_standardized_batch_90.pkl
# Saved: val_standardized_batch_91.pkl
# Saved: val_standardized_batch_92.pkl
# Saved: val_standardized_batch_93.pkl
# Saved: val_standardized_batch_94.pkl
# Saved: val_standardized_batch_95.pkl
# Saved: val_standardized_batch_96.pkl
# Saved: val_standardized_batch_97.pkl
# Saved: val_standardized_batch_98.pkl
# Saved: val_standardized_batch_99.pkl
# Saved: val_standardized_batch_100.pkl
# Saved: val_standardized_batch_101.pkl
# Saved: val_standardized_batch_102.pkl
# Saved: val_standardized_batch_103.pkl
# Saved: val_standardized_batch_104.pkl
# Saved: val_standardized_batch_105.pkl
# Saved: val_standardized_batch_106.pkl
# Saved: val_standardized_batch_107.pkl
# Saved: val_standardized_batch_108.pkl
# Saved: val_standardized_batch_109.pkl
# Saved: val_standardized_batch_110.pkl
# Saved: val_standardized_batch_111.pkl
# Saved: val_standardized_batch_112.pkl
# Saved: val_standardized_batch_113.pkl
# Saved: val_standardized_batch_114.pkl
# Saved: val_standardized_batch_115.pkl
# Saved: val_standardized_batch_116.pkl
# Saved: val_standardized_batch_117.pkl
# Saved: val_standardized_batch_118.pkl
# Saved: val_standardized_batch_119.pkl
# Saved: val_standardized_batch_120.pkl
# Saved: val_standardized_batch_121.pkl
# Saved: val_standardized_batch_122.pkl
# Saved: val_standardized_batch_123.pkl
# Saved: val_standardized_batch_124.pkl
# Saved: val_standardized_batch_125.pkl
# Saved: val_standardized_batch_126.pkl
# Saved: val_standardized_batch_127.pkl
# Saved: val_standardized_batch_128.pkl
# Saved: val_standardized_batch_129.pkl
# Saved: val_standardized_batch_130.pkl
# Saved: val_standardized_batch_131.pkl
# Saved: val_standardized_batch_132.pkl
# Saved: val_standardized_batch_133.pkl
# Saved: val_standardized_batch_134.pkl
# Saved: val_standardized_batch_135.pkl
# Saved: val_standardized_batch_136.pkl
# Saved: val_standardized_batch_137.pkl
# Saved: val_standardized_batch_138.pkl
# Saved: val_standardized_batch_139.pkl
# Saved: val_standardized_batch_140.pkl
# Saved: val_standardized_batch_141.pkl
# Saved: val_standardized_batch_142.pkl
# Saved: val_standardized_batch_143.pkl
# Saved: val_standardized_batch_144.pkl
# Saved: val_standardized_batch_145.pkl
# Saved: val_standardized_batch_146.pkl
# Saved: val_standardized_batch_147.pkl
# Saved: val_standardized_batch_148.pkl
# Saved: val_standardized_batch_149.pkl
# Saved: val_standardized_batch_150.pkl
# Saved: val_standardized_batch_151.pkl
# Saved: val_standardized_batch_152.pkl
# Saved: val_standardized_batch_153.pkl
# Saved: val_standardized_batch_154.pkl
# Saved: val_standardized_batch_155.pkl
# Saved: val_standardized_batch_156.pkl
# Saved: val_standardized_batch_157.pkl
# Saved: val_standardized_batch_158.pkl
# Saved: val_standardized_batch_159.pkl
# Saved: val_standardized_batch_160.pkl
# Saved: val_standardized_batch_161.pkl
# Saved: val_standardized_batch_162.pkl
# Saved: val_standardized_batch_163.pkl
# Saved: val_standardized_batch_164.pkl
# Saved: val_standardized_batch_165.pkl
# Saved: val_standardized_batch_166.pkl
# Saved: val_standardized_batch_167.pkl
# Saved: val_standardized_batch_168.pkl
# Saved: val_standardized_batch_169.pkl
# Saved: val_standardized_batch_170.pkl
# Saved: val_standardized_batch_171.pkl
# Saved: val_standardized_batch_172.pkl
# Saved: val_standardized_batch_173.pkl
# Saved: val_standardized_batch_174.pkl
# Saved: val_standardized_batch_175.pkl
# Saved: val_standardized_batch_176.pkl
# All batches processed.
# Standardization completed and standardized batches saved.

# %%
# Function to combine all processed batches into a single file
def combine_batches(batch_prefix, output_file):
     # Initialize empty lists to store all data and labels
    all_data, all_labels = [], []
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            all_data.append(batch_data)
            all_labels.append(batch_labels)
    # Combine all batch data into a single array        
    combined_data = np.concatenate(all_data)
    # Combine all batch labels into a single array
    combined_labels = np.concatenate(all_labels)
    # Save the combined data and labels into a single output file
    with open(output_file, "wb") as f:
        pickle.dump((combined_data, combined_labels), f)
    print(f"Combined and saved: {output_file}")
# Combine batches for training data into a single file    
combine_batches("train_raw", "train_images_raw.pkl")
# Combine batches for validation data into a single file
combine_batches("val_raw", "val_images_raw.pkl")
# Out:
# Combined and saved: train_images_raw.pkl
# Combined and saved: val_images_raw.pkl

# %% [markdown]
# #### 1.3.5 Data Augmentation (For Neural Network and XGboost)
#  - Applied random flips and resizing to enhance diversity and generalization.

# %%
# Function to resize, augment, and normalize images
def resize_augment_normalize_image(img_id, directory):
    img_path = os.path.join(directory, img_id + ".tif")
    # Define a series of image transformations:
    # 1. Resize the image to 64x64 pixels.
    # 2. Apply a random horizontal flip (mirroring the image).
    # 3. Convert the image to a tensor (a format that machine learning models can understand).
    transform = transforms.Compose([
        transforms.Resize((64, 64)),  
        transforms.RandomHorizontalFlip(),  
        transforms.ToTensor()  
    ])
    # Open the image, apply the transformations, and flatten the image (convert it into a 1D array)
    img = transform(Image.open(img_path)).numpy().flatten()  
    # Normalize the pixel values to be between 0 and 1 (original range is 0-255)
    return img / 255.0  

# Set the batch size for processing images 
BATCH_SIZE_AN=250
# Process the training and validation data (resize, augment, normalize) and save in batches
process_and_save_batches(train_ids, train_labels, train_dir, resize_augment_normalize_image, BATCH_SIZE_AN, "train_normalized_augmented")
process_and_save_batches(val_ids, val_labels, train_dir, resize_augment_normalize_image, BATCH_SIZE_AN, "val_normalized_augmented")
print("Preprocessing complete. Datasets saved.")
# Out:
# Found 0 existing batches. Starting processing...
# Saved: train_normalized_augmented_batch_0.pkl
# Saved: train_normalized_augmented_batch_1.pkl
# Saved: train_normalized_augmented_batch_2.pkl
# Saved: train_normalized_augmented_batch_3.pkl
# Saved: train_normalized_augmented_batch_4.pkl
# Saved: train_normalized_augmented_batch_5.pkl
# Saved: train_normalized_augmented_batch_6.pkl
# Saved: train_normalized_augmented_batch_7.pkl
# Saved: train_normalized_augmented_batch_8.pkl
# Saved: train_normalized_augmented_batch_9.pkl
# Saved: train_normalized_augmented_batch_10.pkl
# Saved: train_normalized_augmented_batch_11.pkl
# Saved: train_normalized_augmented_batch_12.pkl
# Saved: train_normalized_augmented_batch_13.pkl
# Saved: train_normalized_augmented_batch_14.pkl
# Saved: train_normalized_augmented_batch_15.pkl
# Saved: train_normalized_augmented_batch_16.pkl
# Saved: train_normalized_augmented_batch_17.pkl
# Saved: train_normalized_augmented_batch_18.pkl
# Saved: train_normalized_augmented_batch_19.pkl
# Saved: train_normalized_augmented_batch_20.pkl
# Saved: train_normalized_augmented_batch_21.pkl
# Saved: train_normalized_augmented_batch_22.pkl
# Saved: train_normalized_augmented_batch_23.pkl
# Saved: train_normalized_augmented_batch_24.pkl
# Saved: train_normalized_augmented_batch_25.pkl
# Saved: train_normalized_augmented_batch_26.pkl
# Saved: train_normalized_augmented_batch_27.pkl
# Saved: train_normalized_augmented_batch_28.pkl
# Saved: train_normalized_augmented_batch_29.pkl
# Saved: train_normalized_augmented_batch_30.pkl
# Saved: train_normalized_augmented_batch_31.pkl
# Saved: train_normalized_augmented_batch_32.pkl
# Saved: train_normalized_augmented_batch_33.pkl
# Saved: train_normalized_augmented_batch_34.pkl
# Saved: train_normalized_augmented_batch_35.pkl
# Saved: train_normalized_augmented_batch_36.pkl
# Saved: train_normalized_augmented_batch_37.pkl
# Saved: train_normalized_augmented_batch_38.pkl
# Saved: train_normalized_augmented_batch_39.pkl
# Saved: train_normalized_augmented_batch_40.pkl
# Saved: train_normalized_augmented_batch_41.pkl
# Saved: train_normalized_augmented_batch_42.pkl
# Saved: train_normalized_augmented_batch_43.pkl
# Saved: train_normalized_augmented_batch_44.pkl
# Saved: train_normalized_augmented_batch_45.pkl
# Saved: train_normalized_augmented_batch_46.pkl
# Saved: train_normalized_augmented_batch_47.pkl
# Saved: train_normalized_augmented_batch_48.pkl
# Saved: train_normalized_augmented_batch_49.pkl
# Saved: train_normalized_augmented_batch_50.pkl
# Saved: train_normalized_augmented_batch_51.pkl
# Saved: train_normalized_augmented_batch_52.pkl
# Saved: train_normalized_augmented_batch_53.pkl
# Saved: train_normalized_augmented_batch_54.pkl
# Saved: train_normalized_augmented_batch_55.pkl
# Saved: train_normalized_augmented_batch_56.pkl
# Saved: train_normalized_augmented_batch_57.pkl
# Saved: train_normalized_augmented_batch_58.pkl
# Saved: train_normalized_augmented_batch_59.pkl
# Saved: train_normalized_augmented_batch_60.pkl
# Saved: train_normalized_augmented_batch_61.pkl
# Saved: train_normalized_augmented_batch_62.pkl
# Saved: train_normalized_augmented_batch_63.pkl
# Saved: train_normalized_augmented_batch_64.pkl
# Saved: train_normalized_augmented_batch_65.pkl
# Saved: train_normalized_augmented_batch_66.pkl
# Saved: train_normalized_augmented_batch_67.pkl
# Saved: train_normalized_augmented_batch_68.pkl
# Saved: train_normalized_augmented_batch_69.pkl
# Saved: train_normalized_augmented_batch_70.pkl
# Saved: train_normalized_augmented_batch_71.pkl
# Saved: train_normalized_augmented_batch_72.pkl
# Saved: train_normalized_augmented_batch_73.pkl
# Saved: train_normalized_augmented_batch_74.pkl
# Saved: train_normalized_augmented_batch_75.pkl
# Saved: train_normalized_augmented_batch_76.pkl
# Saved: train_normalized_augmented_batch_77.pkl
# Saved: train_normalized_augmented_batch_78.pkl
# Saved: train_normalized_augmented_batch_79.pkl
# Saved: train_normalized_augmented_batch_80.pkl
# Saved: train_normalized_augmented_batch_81.pkl
# Saved: train_normalized_augmented_batch_82.pkl
# Saved: train_normalized_augmented_batch_83.pkl
# Saved: train_normalized_augmented_batch_84.pkl
# Saved: train_normalized_augmented_batch_85.pkl
# Saved: train_normalized_augmented_batch_86.pkl
# Saved: train_normalized_augmented_batch_87.pkl
# Saved: train_normalized_augmented_batch_88.pkl
# Saved: train_normalized_augmented_batch_89.pkl
# Saved: train_normalized_augmented_batch_90.pkl
# Saved: train_normalized_augmented_batch_91.pkl
# Saved: train_normalized_augmented_batch_92.pkl
# Saved: train_normalized_augmented_batch_93.pkl
# Saved: train_normalized_augmented_batch_94.pkl
# Saved: train_normalized_augmented_batch_95.pkl
# Saved: train_normalized_augmented_batch_96.pkl
# Saved: train_normalized_augmented_batch_97.pkl
# Saved: train_normalized_augmented_batch_98.pkl
# Saved: train_normalized_augmented_batch_99.pkl
# Saved: train_normalized_augmented_batch_100.pkl
# Saved: train_normalized_augmented_batch_101.pkl
# Saved: train_normalized_augmented_batch_102.pkl
# Saved: train_normalized_augmented_batch_103.pkl
# Saved: train_normalized_augmented_batch_104.pkl
# Saved: train_normalized_augmented_batch_105.pkl
# Saved: train_normalized_augmented_batch_106.pkl
# Saved: train_normalized_augmented_batch_107.pkl
# Saved: train_normalized_augmented_batch_108.pkl
# Saved: train_normalized_augmented_batch_109.pkl
# Saved: train_normalized_augmented_batch_110.pkl
# Saved: train_normalized_augmented_batch_111.pkl
# Saved: train_normalized_augmented_batch_112.pkl
# Saved: train_normalized_augmented_batch_113.pkl
# Saved: train_normalized_augmented_batch_114.pkl
# Saved: train_normalized_augmented_batch_115.pkl
# Saved: train_normalized_augmented_batch_116.pkl
# Saved: train_normalized_augmented_batch_117.pkl
# Saved: train_normalized_augmented_batch_118.pkl
# Saved: train_normalized_augmented_batch_119.pkl
# Saved: train_normalized_augmented_batch_120.pkl
# Saved: train_normalized_augmented_batch_121.pkl
# Saved: train_normalized_augmented_batch_122.pkl
# Saved: train_normalized_augmented_batch_123.pkl
# Saved: train_normalized_augmented_batch_124.pkl
# Saved: train_normalized_augmented_batch_125.pkl
# Saved: train_normalized_augmented_batch_126.pkl
# Saved: train_normalized_augmented_batch_127.pkl
# Saved: train_normalized_augmented_batch_128.pkl
# Saved: train_normalized_augmented_batch_129.pkl
# Saved: train_normalized_augmented_batch_130.pkl
# Saved: train_normalized_augmented_batch_131.pkl
# Saved: train_normalized_augmented_batch_132.pkl
# Saved: train_normalized_augmented_batch_133.pkl
# Saved: train_normalized_augmented_batch_134.pkl
# Saved: train_normalized_augmented_batch_135.pkl
# Saved: train_normalized_augmented_batch_136.pkl
# Saved: train_normalized_augmented_batch_137.pkl
# Saved: train_normalized_augmented_batch_138.pkl
# Saved: train_normalized_augmented_batch_139.pkl
# Saved: train_normalized_augmented_batch_140.pkl
# Saved: train_normalized_augmented_batch_141.pkl
# Saved: train_normalized_augmented_batch_142.pkl
# Saved: train_normalized_augmented_batch_143.pkl
# Saved: train_normalized_augmented_batch_144.pkl
# Saved: train_normalized_augmented_batch_145.pkl
# Saved: train_normalized_augmented_batch_146.pkl
# Saved: train_normalized_augmented_batch_147.pkl
# Saved: train_normalized_augmented_batch_148.pkl
# Saved: train_normalized_augmented_batch_149.pkl
# Saved: train_normalized_augmented_batch_150.pkl
# Saved: train_normalized_augmented_batch_151.pkl
# Saved: train_normalized_augmented_batch_152.pkl
# Saved: train_normalized_augmented_batch_153.pkl
# Saved: train_normalized_augmented_batch_154.pkl
# Saved: train_normalized_augmented_batch_155.pkl
# Saved: train_normalized_augmented_batch_156.pkl
# Saved: train_normalized_augmented_batch_157.pkl
# Saved: train_normalized_augmented_batch_158.pkl
# Saved: train_normalized_augmented_batch_159.pkl
# Saved: train_normalized_augmented_batch_160.pkl
# Saved: train_normalized_augmented_batch_161.pkl
# Saved: train_normalized_augmented_batch_162.pkl
# Saved: train_normalized_augmented_batch_163.pkl
# Saved: train_normalized_augmented_batch_164.pkl
# Saved: train_normalized_augmented_batch_165.pkl
# Saved: train_normalized_augmented_batch_166.pkl
# Saved: train_normalized_augmented_batch_167.pkl
# Saved: train_normalized_augmented_batch_168.pkl
# Saved: train_normalized_augmented_batch_169.pkl
# Saved: train_normalized_augmented_batch_170.pkl
# Saved: train_normalized_augmented_batch_171.pkl
# Saved: train_normalized_augmented_batch_172.pkl
# Saved: train_normalized_augmented_batch_173.pkl
# Saved: train_normalized_augmented_batch_174.pkl
# Saved: train_normalized_augmented_batch_175.pkl
# Saved: train_normalized_augmented_batch_176.pkl
# Saved: train_normalized_augmented_batch_177.pkl
# Saved: train_normalized_augmented_batch_178.pkl
# Saved: train_normalized_augmented_batch_179.pkl
# Saved: train_normalized_augmented_batch_180.pkl
# Saved: train_normalized_augmented_batch_181.pkl
# Saved: train_normalized_augmented_batch_182.pkl
# Saved: train_normalized_augmented_batch_183.pkl
# Saved: train_normalized_augmented_batch_184.pkl
# Saved: train_normalized_augmented_batch_185.pkl
# Saved: train_normalized_augmented_batch_186.pkl
# Saved: train_normalized_augmented_batch_187.pkl
# Saved: train_normalized_augmented_batch_188.pkl
# Saved: train_normalized_augmented_batch_189.pkl
# Saved: train_normalized_augmented_batch_190.pkl
# Saved: train_normalized_augmented_batch_191.pkl
# Saved: train_normalized_augmented_batch_192.pkl
# Saved: train_normalized_augmented_batch_193.pkl
# Saved: train_normalized_augmented_batch_194.pkl
# Saved: train_normalized_augmented_batch_195.pkl
# Saved: train_normalized_augmented_batch_196.pkl
# Saved: train_normalized_augmented_batch_197.pkl
# Saved: train_normalized_augmented_batch_198.pkl
# Saved: train_normalized_augmented_batch_199.pkl
# Saved: train_normalized_augmented_batch_200.pkl
# Saved: train_normalized_augmented_batch_201.pkl
# Saved: train_normalized_augmented_batch_202.pkl
# Saved: train_normalized_augmented_batch_203.pkl
# Saved: train_normalized_augmented_batch_204.pkl
# Saved: train_normalized_augmented_batch_205.pkl
# Saved: train_normalized_augmented_batch_206.pkl
# Saved: train_normalized_augmented_batch_207.pkl
# Saved: train_normalized_augmented_batch_208.pkl
# Saved: train_normalized_augmented_batch_209.pkl
# Saved: train_normalized_augmented_batch_210.pkl
# Saved: train_normalized_augmented_batch_211.pkl
# Saved: train_normalized_augmented_batch_212.pkl
# Saved: train_normalized_augmented_batch_213.pkl
# Saved: train_normalized_augmented_batch_214.pkl
# Saved: train_normalized_augmented_batch_215.pkl
# Saved: train_normalized_augmented_batch_216.pkl
# Saved: train_normalized_augmented_batch_217.pkl
# Saved: train_normalized_augmented_batch_218.pkl
# Saved: train_normalized_augmented_batch_219.pkl
# Saved: train_normalized_augmented_batch_220.pkl
# Saved: train_normalized_augmented_batch_221.pkl
# Saved: train_normalized_augmented_batch_222.pkl
# Saved: train_normalized_augmented_batch_223.pkl
# Saved: train_normalized_augmented_batch_224.pkl
# Saved: train_normalized_augmented_batch_225.pkl
# Saved: train_normalized_augmented_batch_226.pkl
# Saved: train_normalized_augmented_batch_227.pkl
# Saved: train_normalized_augmented_batch_228.pkl
# Saved: train_normalized_augmented_batch_229.pkl
# Saved: train_normalized_augmented_batch_230.pkl
# Saved: train_normalized_augmented_batch_231.pkl
# Saved: train_normalized_augmented_batch_232.pkl
# Saved: train_normalized_augmented_batch_233.pkl
# Saved: train_normalized_augmented_batch_234.pkl
# Saved: train_normalized_augmented_batch_235.pkl
# Saved: train_normalized_augmented_batch_236.pkl
# Saved: train_normalized_augmented_batch_237.pkl
# Saved: train_normalized_augmented_batch_238.pkl
# Saved: train_normalized_augmented_batch_239.pkl
# Saved: train_normalized_augmented_batch_240.pkl
# Saved: train_normalized_augmented_batch_241.pkl
# Saved: train_normalized_augmented_batch_242.pkl
# Saved: train_normalized_augmented_batch_243.pkl
# Saved: train_normalized_augmented_batch_244.pkl
# Saved: train_normalized_augmented_batch_245.pkl
# Saved: train_normalized_augmented_batch_246.pkl
# Saved: train_normalized_augmented_batch_247.pkl
# Saved: train_normalized_augmented_batch_248.pkl
# Saved: train_normalized_augmented_batch_249.pkl
# Saved: train_normalized_augmented_batch_250.pkl
# Saved: train_normalized_augmented_batch_251.pkl
# Saved: train_normalized_augmented_batch_252.pkl
# Saved: train_normalized_augmented_batch_253.pkl
# Saved: train_normalized_augmented_batch_254.pkl
# Saved: train_normalized_augmented_batch_255.pkl
# Saved: train_normalized_augmented_batch_256.pkl
# Saved: train_normalized_augmented_batch_257.pkl
# Saved: train_normalized_augmented_batch_258.pkl
# Saved: train_normalized_augmented_batch_259.pkl
# Saved: train_normalized_augmented_batch_260.pkl
# Saved: train_normalized_augmented_batch_261.pkl
# Saved: train_normalized_augmented_batch_262.pkl
# Saved: train_normalized_augmented_batch_263.pkl
# Saved: train_normalized_augmented_batch_264.pkl
# Saved: train_normalized_augmented_batch_265.pkl
# Saved: train_normalized_augmented_batch_266.pkl
# Saved: train_normalized_augmented_batch_267.pkl
# Saved: train_normalized_augmented_batch_268.pkl
# Saved: train_normalized_augmented_batch_269.pkl
# Saved: train_normalized_augmented_batch_270.pkl
# Saved: train_normalized_augmented_batch_271.pkl
# Saved: train_normalized_augmented_batch_272.pkl
# Saved: train_normalized_augmented_batch_273.pkl
# Saved: train_normalized_augmented_batch_274.pkl
# Saved: train_normalized_augmented_batch_275.pkl
# Saved: train_normalized_augmented_batch_276.pkl
# Saved: train_normalized_augmented_batch_277.pkl
# Saved: train_normalized_augmented_batch_278.pkl
# Saved: train_normalized_augmented_batch_279.pkl
# Saved: train_normalized_augmented_batch_280.pkl
# Saved: train_normalized_augmented_batch_281.pkl
# Saved: train_normalized_augmented_batch_282.pkl
# Saved: train_normalized_augmented_batch_283.pkl
# Saved: train_normalized_augmented_batch_284.pkl
# Saved: train_normalized_augmented_batch_285.pkl
# Saved: train_normalized_augmented_batch_286.pkl
# Saved: train_normalized_augmented_batch_287.pkl
# Saved: train_normalized_augmented_batch_288.pkl
# Saved: train_normalized_augmented_batch_289.pkl
# Saved: train_normalized_augmented_batch_290.pkl
# Saved: train_normalized_augmented_batch_291.pkl
# Saved: train_normalized_augmented_batch_292.pkl
# Saved: train_normalized_augmented_batch_293.pkl
# Saved: train_normalized_augmented_batch_294.pkl
# Saved: train_normalized_augmented_batch_295.pkl
# Saved: train_normalized_augmented_batch_296.pkl
# Saved: train_normalized_augmented_batch_297.pkl
# Saved: train_normalized_augmented_batch_298.pkl
# Saved: train_normalized_augmented_batch_299.pkl
# Saved: train_normalized_augmented_batch_300.pkl
# Saved: train_normalized_augmented_batch_301.pkl
# Saved: train_normalized_augmented_batch_302.pkl
# Saved: train_normalized_augmented_batch_303.pkl
# Saved: train_normalized_augmented_batch_304.pkl
# Saved: train_normalized_augmented_batch_305.pkl
# Saved: train_normalized_augmented_batch_306.pkl
# Saved: train_normalized_augmented_batch_307.pkl
# Saved: train_normalized_augmented_batch_308.pkl
# Saved: train_normalized_augmented_batch_309.pkl
# Saved: train_normalized_augmented_batch_310.pkl
# Saved: train_normalized_augmented_batch_311.pkl
# Saved: train_normalized_augmented_batch_312.pkl
# Saved: train_normalized_augmented_batch_313.pkl
# Saved: train_normalized_augmented_batch_314.pkl
# Saved: train_normalized_augmented_batch_315.pkl
# Saved: train_normalized_augmented_batch_316.pkl
# Saved: train_normalized_augmented_batch_317.pkl
# Saved: train_normalized_augmented_batch_318.pkl
# Saved: train_normalized_augmented_batch_319.pkl
# Saved: train_normalized_augmented_batch_320.pkl
# Saved: train_normalized_augmented_batch_321.pkl
# Saved: train_normalized_augmented_batch_322.pkl
# Saved: train_normalized_augmented_batch_323.pkl
# Saved: train_normalized_augmented_batch_324.pkl
# Saved: train_normalized_augmented_batch_325.pkl
# Saved: train_normalized_augmented_batch_326.pkl
# Saved: train_normalized_augmented_batch_327.pkl
# Saved: train_normalized_augmented_batch_328.pkl
# Saved: train_normalized_augmented_batch_329.pkl
# Saved: train_normalized_augmented_batch_330.pkl
# Saved: train_normalized_augmented_batch_331.pkl
# Saved: train_normalized_augmented_batch_332.pkl
# Saved: train_normalized_augmented_batch_333.pkl
# Saved: train_normalized_augmented_batch_334.pkl
# Saved: train_normalized_augmented_batch_335.pkl
# Saved: train_normalized_augmented_batch_336.pkl
# Saved: train_normalized_augmented_batch_337.pkl
# Saved: train_normalized_augmented_batch_338.pkl
# Saved: train_normalized_augmented_batch_339.pkl
# Saved: train_normalized_augmented_batch_340.pkl
# Saved: train_normalized_augmented_batch_341.pkl
# Saved: train_normalized_augmented_batch_342.pkl
# Saved: train_normalized_augmented_batch_343.pkl
# Saved: train_normalized_augmented_batch_344.pkl
# Saved: train_normalized_augmented_batch_345.pkl
# Saved: train_normalized_augmented_batch_346.pkl
# Saved: train_normalized_augmented_batch_347.pkl
# Saved: train_normalized_augmented_batch_348.pkl
# Saved: train_normalized_augmented_batch_349.pkl
# Saved: train_normalized_augmented_batch_350.pkl
# Saved: train_normalized_augmented_batch_351.pkl
# Saved: train_normalized_augmented_batch_352.pkl
# Saved: train_normalized_augmented_batch_353.pkl
# Saved: train_normalized_augmented_batch_354.pkl
# Saved: train_normalized_augmented_batch_355.pkl
# Saved: train_normalized_augmented_batch_356.pkl
# Saved: train_normalized_augmented_batch_357.pkl
# Saved: train_normalized_augmented_batch_358.pkl
# Saved: train_normalized_augmented_batch_359.pkl
# Saved: train_normalized_augmented_batch_360.pkl
# Saved: train_normalized_augmented_batch_361.pkl
# Saved: train_normalized_augmented_batch_362.pkl
# Saved: train_normalized_augmented_batch_363.pkl
# Saved: train_normalized_augmented_batch_364.pkl
# Saved: train_normalized_augmented_batch_365.pkl
# Saved: train_normalized_augmented_batch_366.pkl
# Saved: train_normalized_augmented_batch_367.pkl
# Saved: train_normalized_augmented_batch_368.pkl
# Saved: train_normalized_augmented_batch_369.pkl
# Saved: train_normalized_augmented_batch_370.pkl
# Saved: train_normalized_augmented_batch_371.pkl
# Saved: train_normalized_augmented_batch_372.pkl
# Saved: train_normalized_augmented_batch_373.pkl
# Saved: train_normalized_augmented_batch_374.pkl
# Saved: train_normalized_augmented_batch_375.pkl
# Saved: train_normalized_augmented_batch_376.pkl
# Saved: train_normalized_augmented_batch_377.pkl
# Saved: train_normalized_augmented_batch_378.pkl
# Saved: train_normalized_augmented_batch_379.pkl
# Saved: train_normalized_augmented_batch_380.pkl
# Saved: train_normalized_augmented_batch_381.pkl
# Saved: train_normalized_augmented_batch_382.pkl
# Saved: train_normalized_augmented_batch_383.pkl
# Saved: train_normalized_augmented_batch_384.pkl
# Saved: train_normalized_augmented_batch_385.pkl
# Saved: train_normalized_augmented_batch_386.pkl
# Saved: train_normalized_augmented_batch_387.pkl
# Saved: train_normalized_augmented_batch_388.pkl
# Saved: train_normalized_augmented_batch_389.pkl
# Saved: train_normalized_augmented_batch_390.pkl
# Saved: train_normalized_augmented_batch_391.pkl
# Saved: train_normalized_augmented_batch_392.pkl
# Saved: train_normalized_augmented_batch_393.pkl
# Saved: train_normalized_augmented_batch_394.pkl
# Saved: train_normalized_augmented_batch_395.pkl
# Saved: train_normalized_augmented_batch_396.pkl
# Saved: train_normalized_augmented_batch_397.pkl
# Saved: train_normalized_augmented_batch_398.pkl
# Saved: train_normalized_augmented_batch_399.pkl
# Saved: train_normalized_augmented_batch_400.pkl
# Saved: train_normalized_augmented_batch_401.pkl
# Saved: train_normalized_augmented_batch_402.pkl
# Saved: train_normalized_augmented_batch_403.pkl
# Saved: train_normalized_augmented_batch_404.pkl
# Saved: train_normalized_augmented_batch_405.pkl
# Saved: train_normalized_augmented_batch_406.pkl
# Saved: train_normalized_augmented_batch_407.pkl
# Saved: train_normalized_augmented_batch_408.pkl
# Saved: train_normalized_augmented_batch_409.pkl
# Saved: train_normalized_augmented_batch_410.pkl
# Saved: train_normalized_augmented_batch_411.pkl
# Saved: train_normalized_augmented_batch_412.pkl
# Saved: train_normalized_augmented_batch_413.pkl
# Saved: train_normalized_augmented_batch_414.pkl
# Saved: train_normalized_augmented_batch_415.pkl
# Saved: train_normalized_augmented_batch_416.pkl
# Saved: train_normalized_augmented_batch_417.pkl
# Saved: train_normalized_augmented_batch_418.pkl
# Saved: train_normalized_augmented_batch_419.pkl
# Saved: train_normalized_augmented_batch_420.pkl
# Saved: train_normalized_augmented_batch_421.pkl
# Saved: train_normalized_augmented_batch_422.pkl
# Saved: train_normalized_augmented_batch_423.pkl
# Saved: train_normalized_augmented_batch_424.pkl
# Saved: train_normalized_augmented_batch_425.pkl
# Saved: train_normalized_augmented_batch_426.pkl
# Saved: train_normalized_augmented_batch_427.pkl
# Saved: train_normalized_augmented_batch_428.pkl
# Saved: train_normalized_augmented_batch_429.pkl
# Saved: train_normalized_augmented_batch_430.pkl
# Saved: train_normalized_augmented_batch_431.pkl
# Saved: train_normalized_augmented_batch_432.pkl
# Saved: train_normalized_augmented_batch_433.pkl
# Saved: train_normalized_augmented_batch_434.pkl
# Saved: train_normalized_augmented_batch_435.pkl
# Saved: train_normalized_augmented_batch_436.pkl
# Saved: train_normalized_augmented_batch_437.pkl
# Saved: train_normalized_augmented_batch_438.pkl
# Saved: train_normalized_augmented_batch_439.pkl
# Saved: train_normalized_augmented_batch_440.pkl
# Saved: train_normalized_augmented_batch_441.pkl
# Saved: train_normalized_augmented_batch_442.pkl
# Saved: train_normalized_augmented_batch_443.pkl
# Saved: train_normalized_augmented_batch_444.pkl
# Saved: train_normalized_augmented_batch_445.pkl
# Saved: train_normalized_augmented_batch_446.pkl
# Saved: train_normalized_augmented_batch_447.pkl
# Saved: train_normalized_augmented_batch_448.pkl
# Saved: train_normalized_augmented_batch_449.pkl
# Saved: train_normalized_augmented_batch_450.pkl
# Saved: train_normalized_augmented_batch_451.pkl
# Saved: train_normalized_augmented_batch_452.pkl
# Saved: train_normalized_augmented_batch_453.pkl
# Saved: train_normalized_augmented_batch_454.pkl
# Saved: train_normalized_augmented_batch_455.pkl
# Saved: train_normalized_augmented_batch_456.pkl
# Saved: train_normalized_augmented_batch_457.pkl
# Saved: train_normalized_augmented_batch_458.pkl
# Saved: train_normalized_augmented_batch_459.pkl
# Saved: train_normalized_augmented_batch_460.pkl
# Saved: train_normalized_augmented_batch_461.pkl
# Saved: train_normalized_augmented_batch_462.pkl
# Saved: train_normalized_augmented_batch_463.pkl
# Saved: train_normalized_augmented_batch_464.pkl
# Saved: train_normalized_augmented_batch_465.pkl
# Saved: train_normalized_augmented_batch_466.pkl
# Saved: train_normalized_augmented_batch_467.pkl
# Saved: train_normalized_augmented_batch_468.pkl
# Saved: train_normalized_augmented_batch_469.pkl
# Saved: train_normalized_augmented_batch_470.pkl
# Saved: train_normalized_augmented_batch_471.pkl
# Saved: train_normalized_augmented_batch_472.pkl
# Saved: train_normalized_augmented_batch_473.pkl
# Saved: train_normalized_augmented_batch_474.pkl
# Saved: train_normalized_augmented_batch_475.pkl
# Saved: train_normalized_augmented_batch_476.pkl
# Saved: train_normalized_augmented_batch_477.pkl
# Saved: train_normalized_augmented_batch_478.pkl
# Saved: train_normalized_augmented_batch_479.pkl
# Saved: train_normalized_augmented_batch_480.pkl
# Saved: train_normalized_augmented_batch_481.pkl
# Saved: train_normalized_augmented_batch_482.pkl
# Saved: train_normalized_augmented_batch_483.pkl
# Saved: train_normalized_augmented_batch_484.pkl
# Saved: train_normalized_augmented_batch_485.pkl
# Saved: train_normalized_augmented_batch_486.pkl
# Saved: train_normalized_augmented_batch_487.pkl
# Saved: train_normalized_augmented_batch_488.pkl
# Saved: train_normalized_augmented_batch_489.pkl
# Saved: train_normalized_augmented_batch_490.pkl
# Saved: train_normalized_augmented_batch_491.pkl
# Saved: train_normalized_augmented_batch_492.pkl
# Saved: train_normalized_augmented_batch_493.pkl
# Saved: train_normalized_augmented_batch_494.pkl
# Saved: train_normalized_augmented_batch_495.pkl
# Saved: train_normalized_augmented_batch_496.pkl
# Saved: train_normalized_augmented_batch_497.pkl
# Saved: train_normalized_augmented_batch_498.pkl
# Saved: train_normalized_augmented_batch_499.pkl
# Saved: train_normalized_augmented_batch_500.pkl
# Saved: train_normalized_augmented_batch_501.pkl
# Saved: train_normalized_augmented_batch_502.pkl
# Saved: train_normalized_augmented_batch_503.pkl
# Saved: train_normalized_augmented_batch_504.pkl
# Saved: train_normalized_augmented_batch_505.pkl
# Saved: train_normalized_augmented_batch_506.pkl
# Saved: train_normalized_augmented_batch_507.pkl
# Saved: train_normalized_augmented_batch_508.pkl
# Saved: train_normalized_augmented_batch_509.pkl
# Saved: train_normalized_augmented_batch_510.pkl
# Saved: train_normalized_augmented_batch_511.pkl
# Saved: train_normalized_augmented_batch_512.pkl
# Saved: train_normalized_augmented_batch_513.pkl
# Saved: train_normalized_augmented_batch_514.pkl
# Saved: train_normalized_augmented_batch_515.pkl
# Saved: train_normalized_augmented_batch_516.pkl
# Saved: train_normalized_augmented_batch_517.pkl
# Saved: train_normalized_augmented_batch_518.pkl
# Saved: train_normalized_augmented_batch_519.pkl
# Saved: train_normalized_augmented_batch_520.pkl
# Saved: train_normalized_augmented_batch_521.pkl
# Saved: train_normalized_augmented_batch_522.pkl
# Saved: train_normalized_augmented_batch_523.pkl
# Saved: train_normalized_augmented_batch_524.pkl
# Saved: train_normalized_augmented_batch_525.pkl
# Saved: train_normalized_augmented_batch_526.pkl
# Saved: train_normalized_augmented_batch_527.pkl
# Saved: train_normalized_augmented_batch_528.pkl
# Saved: train_normalized_augmented_batch_529.pkl
# Saved: train_normalized_augmented_batch_530.pkl
# Saved: train_normalized_augmented_batch_531.pkl
# Saved: train_normalized_augmented_batch_532.pkl
# Saved: train_normalized_augmented_batch_533.pkl
# Saved: train_normalized_augmented_batch_534.pkl
# Saved: train_normalized_augmented_batch_535.pkl
# Saved: train_normalized_augmented_batch_536.pkl
# Saved: train_normalized_augmented_batch_537.pkl
# Saved: train_normalized_augmented_batch_538.pkl
# Saved: train_normalized_augmented_batch_539.pkl
# Saved: train_normalized_augmented_batch_540.pkl
# Saved: train_normalized_augmented_batch_541.pkl
# Saved: train_normalized_augmented_batch_542.pkl
# Saved: train_normalized_augmented_batch_543.pkl
# Saved: train_normalized_augmented_batch_544.pkl
# Saved: train_normalized_augmented_batch_545.pkl
# Saved: train_normalized_augmented_batch_546.pkl
# Saved: train_normalized_augmented_batch_547.pkl
# Saved: train_normalized_augmented_batch_548.pkl
# Saved: train_normalized_augmented_batch_549.pkl
# Saved: train_normalized_augmented_batch_550.pkl
# Saved: train_normalized_augmented_batch_551.pkl
# Saved: train_normalized_augmented_batch_552.pkl
# Saved: train_normalized_augmented_batch_553.pkl
# Saved: train_normalized_augmented_batch_554.pkl
# Saved: train_normalized_augmented_batch_555.pkl
# Saved: train_normalized_augmented_batch_556.pkl
# Saved: train_normalized_augmented_batch_557.pkl
# Saved: train_normalized_augmented_batch_558.pkl
# Saved: train_normalized_augmented_batch_559.pkl
# Saved: train_normalized_augmented_batch_560.pkl
# Saved: train_normalized_augmented_batch_561.pkl
# Saved: train_normalized_augmented_batch_562.pkl
# Saved: train_normalized_augmented_batch_563.pkl
# Saved: train_normalized_augmented_batch_564.pkl
# Saved: train_normalized_augmented_batch_565.pkl
# Saved: train_normalized_augmented_batch_566.pkl
# Saved: train_normalized_augmented_batch_567.pkl
# Saved: train_normalized_augmented_batch_568.pkl
# Saved: train_normalized_augmented_batch_569.pkl
# Saved: train_normalized_augmented_batch_570.pkl
# Saved: train_normalized_augmented_batch_571.pkl
# Saved: train_normalized_augmented_batch_572.pkl
# Saved: train_normalized_augmented_batch_573.pkl
# Saved: train_normalized_augmented_batch_574.pkl
# Saved: train_normalized_augmented_batch_575.pkl
# Saved: train_normalized_augmented_batch_576.pkl
# Saved: train_normalized_augmented_batch_577.pkl
# Saved: train_normalized_augmented_batch_578.pkl
# Saved: train_normalized_augmented_batch_579.pkl
# Saved: train_normalized_augmented_batch_580.pkl
# Saved: train_normalized_augmented_batch_581.pkl
# Saved: train_normalized_augmented_batch_582.pkl
# Saved: train_normalized_augmented_batch_583.pkl
# Saved: train_normalized_augmented_batch_584.pkl
# Saved: train_normalized_augmented_batch_585.pkl
# Saved: train_normalized_augmented_batch_586.pkl
# Saved: train_normalized_augmented_batch_587.pkl
# Saved: train_normalized_augmented_batch_588.pkl
# Saved: train_normalized_augmented_batch_589.pkl
# Saved: train_normalized_augmented_batch_590.pkl
# Saved: train_normalized_augmented_batch_591.pkl
# Saved: train_normalized_augmented_batch_592.pkl
# Saved: train_normalized_augmented_batch_593.pkl
# Saved: train_normalized_augmented_batch_594.pkl
# Saved: train_normalized_augmented_batch_595.pkl
# Saved: train_normalized_augmented_batch_596.pkl
# Saved: train_normalized_augmented_batch_597.pkl
# Saved: train_normalized_augmented_batch_598.pkl
# Saved: train_normalized_augmented_batch_599.pkl
# Saved: train_normalized_augmented_batch_600.pkl
# Saved: train_normalized_augmented_batch_601.pkl
# Saved: train_normalized_augmented_batch_602.pkl
# Saved: train_normalized_augmented_batch_603.pkl
# Saved: train_normalized_augmented_batch_604.pkl
# Saved: train_normalized_augmented_batch_605.pkl
# Saved: train_normalized_augmented_batch_606.pkl
# Saved: train_normalized_augmented_batch_607.pkl
# Saved: train_normalized_augmented_batch_608.pkl
# Saved: train_normalized_augmented_batch_609.pkl
# Saved: train_normalized_augmented_batch_610.pkl
# Saved: train_normalized_augmented_batch_611.pkl
# Saved: train_normalized_augmented_batch_612.pkl
# Saved: train_normalized_augmented_batch_613.pkl
# Saved: train_normalized_augmented_batch_614.pkl
# Saved: train_normalized_augmented_batch_615.pkl
# Saved: train_normalized_augmented_batch_616.pkl
# Saved: train_normalized_augmented_batch_617.pkl
# Saved: train_normalized_augmented_batch_618.pkl
# Saved: train_normalized_augmented_batch_619.pkl
# Saved: train_normalized_augmented_batch_620.pkl
# Saved: train_normalized_augmented_batch_621.pkl
# Saved: train_normalized_augmented_batch_622.pkl
# Saved: train_normalized_augmented_batch_623.pkl
# Saved: train_normalized_augmented_batch_624.pkl
# Saved: train_normalized_augmented_batch_625.pkl
# Saved: train_normalized_augmented_batch_626.pkl
# Saved: train_normalized_augmented_batch_627.pkl
# Saved: train_normalized_augmented_batch_628.pkl
# Saved: train_normalized_augmented_batch_629.pkl
# Saved: train_normalized_augmented_batch_630.pkl
# Saved: train_normalized_augmented_batch_631.pkl
# Saved: train_normalized_augmented_batch_632.pkl
# Saved: train_normalized_augmented_batch_633.pkl
# Saved: train_normalized_augmented_batch_634.pkl
# Saved: train_normalized_augmented_batch_635.pkl
# Saved: train_normalized_augmented_batch_636.pkl
# Saved: train_normalized_augmented_batch_637.pkl
# Saved: train_normalized_augmented_batch_638.pkl
# Saved: train_normalized_augmented_batch_639.pkl
# Saved: train_normalized_augmented_batch_640.pkl
# Saved: train_normalized_augmented_batch_641.pkl
# Saved: train_normalized_augmented_batch_642.pkl
# Saved: train_normalized_augmented_batch_643.pkl
# Saved: train_normalized_augmented_batch_644.pkl
# Saved: train_normalized_augmented_batch_645.pkl
# Saved: train_normalized_augmented_batch_646.pkl
# Saved: train_normalized_augmented_batch_647.pkl
# Saved: train_normalized_augmented_batch_648.pkl
# Saved: train_normalized_augmented_batch_649.pkl
# Saved: train_normalized_augmented_batch_650.pkl
# Saved: train_normalized_augmented_batch_651.pkl
# Saved: train_normalized_augmented_batch_652.pkl
# Saved: train_normalized_augmented_batch_653.pkl
# Saved: train_normalized_augmented_batch_654.pkl
# Saved: train_normalized_augmented_batch_655.pkl
# Saved: train_normalized_augmented_batch_656.pkl
# Saved: train_normalized_augmented_batch_657.pkl
# Saved: train_normalized_augmented_batch_658.pkl
# Saved: train_normalized_augmented_batch_659.pkl
# Saved: train_normalized_augmented_batch_660.pkl
# Saved: train_normalized_augmented_batch_661.pkl
# Saved: train_normalized_augmented_batch_662.pkl
# Saved: train_normalized_augmented_batch_663.pkl
# Saved: train_normalized_augmented_batch_664.pkl
# Saved: train_normalized_augmented_batch_665.pkl
# Saved: train_normalized_augmented_batch_666.pkl
# Saved: train_normalized_augmented_batch_667.pkl
# Saved: train_normalized_augmented_batch_668.pkl
# Saved: train_normalized_augmented_batch_669.pkl
# Saved: train_normalized_augmented_batch_670.pkl
# Saved: train_normalized_augmented_batch_671.pkl
# Saved: train_normalized_augmented_batch_672.pkl
# Saved: train_normalized_augmented_batch_673.pkl
# Saved: train_normalized_augmented_batch_674.pkl
# Saved: train_normalized_augmented_batch_675.pkl
# Saved: train_normalized_augmented_batch_676.pkl
# Saved: train_normalized_augmented_batch_677.pkl
# Saved: train_normalized_augmented_batch_678.pkl
# Saved: train_normalized_augmented_batch_679.pkl
# Saved: train_normalized_augmented_batch_680.pkl
# Saved: train_normalized_augmented_batch_681.pkl
# Saved: train_normalized_augmented_batch_682.pkl
# Saved: train_normalized_augmented_batch_683.pkl
# Saved: train_normalized_augmented_batch_684.pkl
# Saved: train_normalized_augmented_batch_685.pkl
# Saved: train_normalized_augmented_batch_686.pkl
# Saved: train_normalized_augmented_batch_687.pkl
# Saved: train_normalized_augmented_batch_688.pkl
# Saved: train_normalized_augmented_batch_689.pkl
# Saved: train_normalized_augmented_batch_690.pkl
# Saved: train_normalized_augmented_batch_691.pkl
# Saved: train_normalized_augmented_batch_692.pkl
# Saved: train_normalized_augmented_batch_693.pkl
# Saved: train_normalized_augmented_batch_694.pkl
# Saved: train_normalized_augmented_batch_695.pkl
# Saved: train_normalized_augmented_batch_696.pkl
# Saved: train_normalized_augmented_batch_697.pkl
# Saved: train_normalized_augmented_batch_698.pkl
# Saved: train_normalized_augmented_batch_699.pkl
# Saved: train_normalized_augmented_batch_700.pkl
# Saved: train_normalized_augmented_batch_701.pkl
# Saved: train_normalized_augmented_batch_702.pkl
# Saved: train_normalized_augmented_batch_703.pkl
# Saved: train_normalized_augmented_batch_704.pkl
# All batches processed.
# Found 0 existing batches. Starting processing...
# Saved: val_normalized_augmented_batch_0.pkl
# Saved: val_normalized_augmented_batch_1.pkl
# Saved: val_normalized_augmented_batch_2.pkl
# Saved: val_normalized_augmented_batch_3.pkl
# Saved: val_normalized_augmented_batch_4.pkl
# Saved: val_normalized_augmented_batch_5.pkl
# Saved: val_normalized_augmented_batch_6.pkl
# Saved: val_normalized_augmented_batch_7.pkl
# Saved: val_normalized_augmented_batch_8.pkl
# Saved: val_normalized_augmented_batch_9.pkl
# Saved: val_normalized_augmented_batch_10.pkl
# Saved: val_normalized_augmented_batch_11.pkl
# Saved: val_normalized_augmented_batch_12.pkl
# Saved: val_normalized_augmented_batch_13.pkl
# Saved: val_normalized_augmented_batch_14.pkl
# Saved: val_normalized_augmented_batch_15.pkl
# Saved: val_normalized_augmented_batch_16.pkl
# Saved: val_normalized_augmented_batch_17.pkl
# Saved: val_normalized_augmented_batch_18.pkl
# Saved: val_normalized_augmented_batch_19.pkl
# Saved: val_normalized_augmented_batch_20.pkl
# Saved: val_normalized_augmented_batch_21.pkl
# Saved: val_normalized_augmented_batch_22.pkl
# Saved: val_normalized_augmented_batch_23.pkl
# Saved: val_normalized_augmented_batch_24.pkl
# Saved: val_normalized_augmented_batch_25.pkl
# Saved: val_normalized_augmented_batch_26.pkl
# Saved: val_normalized_augmented_batch_27.pkl
# Saved: val_normalized_augmented_batch_28.pkl
# Saved: val_normalized_augmented_batch_29.pkl
# Saved: val_normalized_augmented_batch_30.pkl
# Saved: val_normalized_augmented_batch_31.pkl
# Saved: val_normalized_augmented_batch_32.pkl
# Saved: val_normalized_augmented_batch_33.pkl
# Saved: val_normalized_augmented_batch_34.pkl
# Saved: val_normalized_augmented_batch_35.pkl
# Saved: val_normalized_augmented_batch_36.pkl
# Saved: val_normalized_augmented_batch_37.pkl
# Saved: val_normalized_augmented_batch_38.pkl
# Saved: val_normalized_augmented_batch_39.pkl
# Saved: val_normalized_augmented_batch_40.pkl
# Saved: val_normalized_augmented_batch_41.pkl
# Saved: val_normalized_augmented_batch_42.pkl
# Saved: val_normalized_augmented_batch_43.pkl
# Saved: val_normalized_augmented_batch_44.pkl
# Saved: val_normalized_augmented_batch_45.pkl
# Saved: val_normalized_augmented_batch_46.pkl
# Saved: val_normalized_augmented_batch_47.pkl
# Saved: val_normalized_augmented_batch_48.pkl
# Saved: val_normalized_augmented_batch_49.pkl
# Saved: val_normalized_augmented_batch_50.pkl
# Saved: val_normalized_augmented_batch_51.pkl
# Saved: val_normalized_augmented_batch_52.pkl
# Saved: val_normalized_augmented_batch_53.pkl
# Saved: val_normalized_augmented_batch_54.pkl
# Saved: val_normalized_augmented_batch_55.pkl
# Saved: val_normalized_augmented_batch_56.pkl
# Saved: val_normalized_augmented_batch_57.pkl
# Saved: val_normalized_augmented_batch_58.pkl
# Saved: val_normalized_augmented_batch_59.pkl
# Saved: val_normalized_augmented_batch_60.pkl
# Saved: val_normalized_augmented_batch_61.pkl
# Saved: val_normalized_augmented_batch_62.pkl
# Saved: val_normalized_augmented_batch_63.pkl
# Saved: val_normalized_augmented_batch_64.pkl
# Saved: val_normalized_augmented_batch_65.pkl
# Saved: val_normalized_augmented_batch_66.pkl
# Saved: val_normalized_augmented_batch_67.pkl
# Saved: val_normalized_augmented_batch_68.pkl
# Saved: val_normalized_augmented_batch_69.pkl
# Saved: val_normalized_augmented_batch_70.pkl
# Saved: val_normalized_augmented_batch_71.pkl
# Saved: val_normalized_augmented_batch_72.pkl
# Saved: val_normalized_augmented_batch_73.pkl
# Saved: val_normalized_augmented_batch_74.pkl
# Saved: val_normalized_augmented_batch_75.pkl
# Saved: val_normalized_augmented_batch_76.pkl
# Saved: val_normalized_augmented_batch_77.pkl
# Saved: val_normalized_augmented_batch_78.pkl
# Saved: val_normalized_augmented_batch_79.pkl
# Saved: val_normalized_augmented_batch_80.pkl
# Saved: val_normalized_augmented_batch_81.pkl
# Saved: val_normalized_augmented_batch_82.pkl
# Saved: val_normalized_augmented_batch_83.pkl
# Saved: val_normalized_augmented_batch_84.pkl
# Saved: val_normalized_augmented_batch_85.pkl
# Saved: val_normalized_augmented_batch_86.pkl
# Saved: val_normalized_augmented_batch_87.pkl
# Saved: val_normalized_augmented_batch_88.pkl
# Saved: val_normalized_augmented_batch_89.pkl
# Saved: val_normalized_augmented_batch_90.pkl
# Saved: val_normalized_augmented_batch_91.pkl
# Saved: val_normalized_augmented_batch_92.pkl
# Saved: val_normalized_augmented_batch_93.pkl
# Saved: val_normalized_augmented_batch_94.pkl
# Saved: val_normalized_augmented_batch_95.pkl
# Saved: val_normalized_augmented_batch_96.pkl
# Saved: val_normalized_augmented_batch_97.pkl
# Saved: val_normalized_augmented_batch_98.pkl
# Saved: val_normalized_augmented_batch_99.pkl
# Saved: val_normalized_augmented_batch_100.pkl
# Saved: val_normalized_augmented_batch_101.pkl
# Saved: val_normalized_augmented_batch_102.pkl
# Saved: val_normalized_augmented_batch_103.pkl
# Saved: val_normalized_augmented_batch_104.pkl
# Saved: val_normalized_augmented_batch_105.pkl
# Saved: val_normalized_augmented_batch_106.pkl
# Saved: val_normalized_augmented_batch_107.pkl
# Saved: val_normalized_augmented_batch_108.pkl
# Saved: val_normalized_augmented_batch_109.pkl
# Saved: val_normalized_augmented_batch_110.pkl
# Saved: val_normalized_augmented_batch_111.pkl
# Saved: val_normalized_augmented_batch_112.pkl
# Saved: val_normalized_augmented_batch_113.pkl
# Saved: val_normalized_augmented_batch_114.pkl
# Saved: val_normalized_augmented_batch_115.pkl
# Saved: val_normalized_augmented_batch_116.pkl
# Saved: val_normalized_augmented_batch_117.pkl
# Saved: val_normalized_augmented_batch_118.pkl
# Saved: val_normalized_augmented_batch_119.pkl
# Saved: val_normalized_augmented_batch_120.pkl
# Saved: val_normalized_augmented_batch_121.pkl
# Saved: val_normalized_augmented_batch_122.pkl
# Saved: val_normalized_augmented_batch_123.pkl
# Saved: val_normalized_augmented_batch_124.pkl
# Saved: val_normalized_augmented_batch_125.pkl
# Saved: val_normalized_augmented_batch_126.pkl
# Saved: val_normalized_augmented_batch_127.pkl
# Saved: val_normalized_augmented_batch_128.pkl
# Saved: val_normalized_augmented_batch_129.pkl
# Saved: val_normalized_augmented_batch_130.pkl
# Saved: val_normalized_augmented_batch_131.pkl
# Saved: val_normalized_augmented_batch_132.pkl
# Saved: val_normalized_augmented_batch_133.pkl
# Saved: val_normalized_augmented_batch_134.pkl
# Saved: val_normalized_augmented_batch_135.pkl
# Saved: val_normalized_augmented_batch_136.pkl
# Saved: val_normalized_augmented_batch_137.pkl
# Saved: val_normalized_augmented_batch_138.pkl
# Saved: val_normalized_augmented_batch_139.pkl
# Saved: val_normalized_augmented_batch_140.pkl
# Saved: val_normalized_augmented_batch_141.pkl
# Saved: val_normalized_augmented_batch_142.pkl
# Saved: val_normalized_augmented_batch_143.pkl
# Saved: val_normalized_augmented_batch_144.pkl
# Saved: val_normalized_augmented_batch_145.pkl
# Saved: val_normalized_augmented_batch_146.pkl
# Saved: val_normalized_augmented_batch_147.pkl
# Saved: val_normalized_augmented_batch_148.pkl
# Saved: val_normalized_augmented_batch_149.pkl
# Saved: val_normalized_augmented_batch_150.pkl
# Saved: val_normalized_augmented_batch_151.pkl
# Saved: val_normalized_augmented_batch_152.pkl
# Saved: val_normalized_augmented_batch_153.pkl
# Saved: val_normalized_augmented_batch_154.pkl
# Saved: val_normalized_augmented_batch_155.pkl
# Saved: val_normalized_augmented_batch_156.pkl
# Saved: val_normalized_augmented_batch_157.pkl
# Saved: val_normalized_augmented_batch_158.pkl
# Saved: val_normalized_augmented_batch_159.pkl
# Saved: val_normalized_augmented_batch_160.pkl
# Saved: val_normalized_augmented_batch_161.pkl
# Saved: val_normalized_augmented_batch_162.pkl
# Saved: val_normalized_augmented_batch_163.pkl
# Saved: val_normalized_augmented_batch_164.pkl
# Saved: val_normalized_augmented_batch_165.pkl
# Saved: val_normalized_augmented_batch_166.pkl
# Saved: val_normalized_augmented_batch_167.pkl
# Saved: val_normalized_augmented_batch_168.pkl
# Saved: val_normalized_augmented_batch_169.pkl
# Saved: val_normalized_augmented_batch_170.pkl
# Saved: val_normalized_augmented_batch_171.pkl
# Saved: val_normalized_augmented_batch_172.pkl
# Saved: val_normalized_augmented_batch_173.pkl
# Saved: val_normalized_augmented_batch_174.pkl
# Saved: val_normalized_augmented_batch_175.pkl
# Saved: val_normalized_augmented_batch_176.pkl
# All batches processed.
# Preprocessing complete. Datasets saved.

# %% [markdown]
# ## 2. Model Training and Comparison

# %% [markdown]
# ### 2.1 Naive Bayes

# %% [markdown]
# 1. **Key Features**
#     - Assumes independence between features.
#     - Efficient for large datasets.
# 2. **Preprocessing**
#     - Used raw pixel values without scaling or normalization.

# %%
# Function to load pre-processed batches of data from files
def load_batches(batch_prefix):
    import glob
    import pickle
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            yield batch_data, batch_labels

# Create a Naive Bayes model for classification
naive_bayes_model = GaussianNB()

# Train the model in batches using the pre-processed training data
for train_batch, train_labels_batch in load_batches("train_raw"):
    naive_bayes_model.partial_fit(train_batch, train_labels_batch, classes=np.array([0, 1]))  # Use `partial_fit` for batch learning
print("Naive Bayes model training completed.")

# Initialize lists to store all validation labels and predictions
all_val_labels = []
all_val_predictions = []

for val_batch, val_labels_batch in load_batches("val_raw"):
    val_predictions_batch = naive_bayes_model.predict(val_batch)
    all_val_labels.extend(val_labels_batch)
    all_val_predictions.extend(val_predictions_batch)
all_val_labels = np.array(all_val_labels)
all_val_predictions = np.array(all_val_predictions)


accuracy = accuracy_score(all_val_labels, all_val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(all_val_labels, all_val_predictions, target_names=["Negative", "Positive"]))
print("Confusion Matrix:")
print(confusion_matrix(all_val_labels, all_val_predictions))

# Save the trained model to a file for later use
dump(naive_bayes_model, "naive_bayes_model.joblib")
print("Naive Bayes model saved.")
# Out:
# Naive Bayes model training completed.
# Validation Accuracy: 0.73
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.70      0.76     26182
#     Positive       0.64      0.78      0.70     17823
#
#     accuracy                           0.73     44005
#    macro avg       0.73      0.74      0.73     44005
# weighted avg       0.75      0.73      0.73     44005
#
# Confusion Matrix:
# [[18333  7849]
#  [ 4008 13815]]
# Naive Bayes model saved.

# %%
conf_matrix = confusion_matrix(all_val_labels, all_val_predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### 2.2 Random Forest

# %% [markdown]
# 1. **Key Features**
#     - Ensemble method using decision trees.
#     - Captures feature importance and non-linear relationships.

# %%
# Function to load data batches
def load_batches(batch_prefix):
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            yield batch_data, batch_labels

# Training the Model
random_forest_model = RandomForestClassifier(random_state=42)
for train_batch, train_labels_batch in load_batches("train_raw"):
    random_forest_model.fit(train_batch, train_labels_batch)  
print("Random Forest model training completed.")

# Evaluate the model on validation data batches
all_val_labels = []
all_val_predictions = []
for val_batch, val_labels_batch in load_batches("val_raw"):
    val_predictions_batch = random_forest_model.predict(val_batch)
    all_val_labels.extend(val_labels_batch)
    all_val_predictions.extend(val_predictions_batch)
# Convert the collected validation labels and predictions into NumPy arrays
all_val_labels = np.array(all_val_labels)
all_val_predictions = np.array(all_val_predictions)

# Evaluation
accuracy = accuracy_score(all_val_labels, all_val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(all_val_labels, all_val_predictions, target_names=["Negative", "Positive"]))
conf_matrix = confusion_matrix(all_val_labels, all_val_predictions)
print("Confusion Matrix:")
print(conf_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Save the trained Random Forest model to a file for future use
dump(random_forest_model, "random_forest_model.joblib")
print("Random Forest model saved.")
# Out:
# Random Forest model training completed.
# Validation Accuracy: 0.75
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.74      0.89      0.81     26182
#     Positive       0.78      0.55      0.64     17823
#
#     accuracy                           0.75     44005
#    macro avg       0.76      0.72      0.73     44005
# weighted avg       0.76      0.75      0.74     44005
#
# Confusion Matrix:
# [[23362  2820]
#  [ 8088  9735]]
# Random Forest model saved.

# %% [markdown]
# ### 2.3 Logistic Regression

# %% [markdown]
# 1. **Key Features**
#     - Linear classification model.
#     - Uses sigmoid activation to predict probabilities.
# 2. **Enhancements**
#     - Added L2 regularization for improved generalization.
#     - Applied probability calibration (Isotonic Regression).
#     - Logistic Regression inherently outputs probabilities for binary classification. However, these probabilities are not always well-calibrated, especially in cases with imbalanced datasets or when regularization is applied during training. Calibration ensures that the predicted probabilities are aligned with the true likelihood of an event.
#     - we used Isotonic Regression because it works well with more complex probability distributions.

# %%
# Function to load processed data batches
def load_batches(batch_prefix):
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            yield batch_data, batch_labels
            
# Function to combine all validation batches into a single dataset
def combine_validation_batches(batch_prefix):
    all_data, all_labels = [], []
    for val_batch, val_labels_batch in load_batches(batch_prefix):
        all_data.extend(val_batch)
        all_labels.extend(val_labels_batch)
    return np.array(all_data), np.array(all_labels)

# Load all validation data and labels
val_data, val_labels = combine_validation_batches("val_standardized")

# Initialize a logistic regression model using Stochastic Gradient Descent
logistic_model = SGDClassifier(
    loss="log_loss", penalty="l2", max_iter=1000, tol=1e-3, random_state=42
)
# print("Training Logistic Regression with Batches...")
first_batch = True
for train_batch, train_labels_batch in load_batches("train_standardized"):
    if first_batch:
        smote = SMOTE(random_state=42)
        train_batch, train_labels_batch = smote.fit_resample(train_batch, train_labels_batch)
        logistic_model.fit(train_batch, train_labels_batch)  
        first_batch = False
    else:
        logistic_model.fit(train_batch, train_labels_batch)  
print("Logistic Regression model training completed.")

# Calibrate the model to output better probabilities
calibrated_model = CalibratedClassifierCV(estimator=logistic_model, method='isotonic', cv='prefit')
calibrated_model.fit(val_data, val_labels)
print("Probability calibration completed.")

# Evaluation
val_probabilities = calibrated_model.predict_proba(val_data)[:, 1]  
val_predictions = (val_probabilities > 0.5).astype(int) 
accuracy = accuracy_score(val_labels, val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(val_labels, val_predictions, target_names=["Negative", "Positive"]))
conf_matrix = confusion_matrix(val_labels, val_predictions)
print("Confusion Matrix:")
print(conf_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

precision, recall, _ = precision_recall_curve(val_labels, val_probabilities)
pr_auc = auc(recall, precision)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f"PR Curve (AUC = {pr_auc:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

fpr, tpr, _ = roc_curve(val_labels, val_probabilities)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Save the calibrated model to a file for future use
dump(calibrated_model, "logistic_regression_calibrated.joblib")
print("Calibrated Logistic Regression model saved.")
# Out:
# Training Logistic Regression with Batches...
# Logistic Regression model training completed.
# Probability calibration completed.
# Validation Accuracy: 0.63
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.66      0.79      0.72     26182
#     Positive       0.57      0.41      0.47     17823
#
#     accuracy                           0.63     44005
#    macro avg       0.61      0.60      0.60     44005
# weighted avg       0.62      0.63      0.62     44005
#
# Confusion Matrix:
# [[20616  5566]
#  [10544  7279]]
# Calibrated Logistic Regression model saved.

# %% [markdown]
# ### 2.4 SVM

# %% [markdown]
# 1. **Key Features**
#     - Finds an optimal hyperplane for classification.
#     - Uses kernel functions for non-linear decision boundaries.

# %%
# Function to load data batches from files
def load_batches(batch_prefix):
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            yield batch_data, batch_labels
            
# Initialize and train an SVM model
#print("Training SVM with Batches...")
svm_model = SVC(kernel="rbf", C=1.0, gamma="scale", probability=True, random_state=42)  
for train_batch, train_labels_batch in load_batches("train_standardized"):
    svm_model.fit(train_batch, train_labels_batch)  
print("SVM model training completed.")
print("Evaluating on Validation Set...")
all_val_labels = []
all_val_predictions = []
all_val_probabilities = []

# Process the validation data in batches
for val_batch, val_labels_batch in load_batches("val_standardized"):
    val_predictions_batch = svm_model.predict(val_batch)
    val_probabilities_batch = svm_model.predict_proba(val_batch)[:, 1]  
    all_val_labels.extend(val_labels_batch)
    all_val_predictions.extend(val_predictions_batch)
    all_val_probabilities.extend(val_probabilities_batch)
# Convert lists to numpy arrays for further analysis    
all_val_labels = np.array(all_val_labels)
all_val_predictions = np.array(all_val_predictions)
all_val_probabilities = np.array(all_val_probabilities)

# Evaluation
accuracy = accuracy_score(all_val_labels, all_val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(all_val_labels, all_val_predictions, target_names=["Negative", "Positive"]))
conf_matrix = confusion_matrix(all_val_labels, all_val_predictions)
print("Confusion Matrix:")
print(conf_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

precision, recall, _ = precision_recall_curve(all_val_labels, all_val_probabilities)
pr_auc = auc(recall, precision)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f"PR Curve (AUC = {pr_auc:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

fpr, tpr, _ = roc_curve(all_val_labels, all_val_probabilities)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Save the trained SVM model to a file
dump(svm_model, "svm_model_with_curves.joblib")
print("SVM model saved.")
# Out:
# SVM model training completed.
# Evaluating on Validation Set...
# Validation Accuracy: 0.76
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.81      0.79      0.80     26182
#     Positive       0.70      0.73      0.72     17823
#
#     accuracy                           0.76     44005
#    macro avg       0.76      0.76      0.76     44005
# weighted avg       0.77      0.76      0.77     44005
#
# Confusion Matrix:
# [[20575  5607]
#  [ 4742 13081]]
# SVM model saved.

# %% [markdown]
# ### 2.5 Neural Network

# %% [markdown]
# #### 2.5.1 Neural Network 1
#
# #### Initial Implementation
#
# 1. **Architecture:**
#     - Input Layer: 1024 neurons (flattened image).
#     - Hidden Layers: 2 layers with 512 and 256 neurons.
#     - Activation: ReLU for hidden layers, Sigmoid for the output layer.
#     - Dropout: Added 20% dropout to reduce overfitting.
# 2. **Training:**
#     - Batch Size: 32
#     - Epochs: 5
#     - Optimizer: Adam
#     - Learning Rate: 0.001
# 3. **Data Handling:**
#     - Used normalized and augmented training data.
#     - Did not explicitly address class imbalance.

# %%
# Check if GPU is available for faster processing; otherwise, use CPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Function to load batches of preprocessed data from saved files
def load_batches(batch_prefix):
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            yield batch_data, batch_labels

# Define a simple Neural Network structure
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(64 * 64 * 3, 256),  
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Sigmoid()  
        )
 # Define how the input data flows through the network
    def forward(self, x):
        return self.fc(x)
        
# Initialize the Neural Network and move it to the device (CPU/GPU)
model = NeuralNetwork().to(device)
# Define the loss function (Binary Cross-Entropy Loss for binary classification)
criterion = nn.BCELoss()  
# Define the optimizer (Adam optimizer for updating weights during training)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Start training the Neural Network
print("Training Neural Network with Batches...")
model.train()
for train_batch, train_labels_batch in load_batches("train_normalized_augmented"):
    train_batch = torch.tensor(train_batch, dtype=torch.float32).to(device)
    train_labels_batch = torch.tensor(train_labels_batch, dtype=torch.float32).view(-1, 1).to(device)
    outputs = model(train_batch)     # Forward pass: Get predictions from the model
    loss = criterion(outputs, train_labels_batch)     # Calculate the loss
    optimizer.zero_grad()     # Zero the gradients to prevent accumulation
    loss.backward()    # Backward pass: Compute gradients
    optimizer.step()     # Update model weights
print("Neural Network training completed.")


# Evaluate the model on the validation set
print("Evaluating on Validation Set...")
model.eval()
all_val_labels = []
all_val_predictions = []
all_val_probabilities = []

# Disable gradient computation during evaluation for efficiency
with torch.no_grad():
    for val_batch, val_labels_batch in load_batches("val_normalized_augmented"):
        # Convert validation data to tensors and move them to the device
        val_batch = torch.tensor(val_batch, dtype=torch.float32).to(device)
        val_labels_batch = np.array(val_labels_batch)
        # Get model probabilities for each input
        probabilities = model(val_batch).cpu().numpy().flatten()
        predictions = (probabilities > 0.5).astype(int)  # Threshold at 0.5
        # Collect true labels, predicted labels, and probabilities for later analysis
        all_val_labels.extend(val_labels_batch)
        all_val_predictions.extend(predictions)
        all_val_probabilities.extend(probabilities)
all_val_labels = np.array(all_val_labels)
all_val_predictions = np.array(all_val_predictions)
all_val_probabilities = np.array(all_val_probabilities)

accuracy = accuracy_score(all_val_labels, all_val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(all_val_labels, all_val_predictions, target_names=["Negative", "Positive"]))
conf_matrix = confusion_matrix(all_val_labels, all_val_predictions)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

precision, recall, _ = precision_recall_curve(all_val_labels, all_val_probabilities)
pr_auc = auc(recall, precision)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f"PR Curve (AUC = {pr_auc:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

fpr, tpr, _ = roc_curve(all_val_labels, all_val_probabilities)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

torch.save(model.state_dict(), "neural_network_model.pth")
print("Neural Network model saved.")
# Out:
# Training Neural Network with Batches...
# Neural Network training completed.
# Evaluating on Validation Set...
# Validation Accuracy: 0.70
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.64      0.72     26182
#     Positive       0.60      0.80      0.69     17823
#
#     accuracy                           0.70     44005
#    macro avg       0.71      0.72      0.70     44005
# weighted avg       0.73      0.70      0.71     44005
#
# Confusion Matrix:
# [[16712  9470]
#  [ 3589 14234]]
# Neural Network model saved.

# %% [markdown]
# ## Improved Neural Network Model
#
# Building on the original **Neural Network model**, the following improvements were made:
#
# 1. **Neural Network Architecture**
#     - **Increased Neurons**: Added more neurons in each layer to enhance the network's capacity to capture complex patterns.
#     - **Activation Functions**: Replaced standard ReLU with **LeakyReLU** for better gradient flow and used ReLU in the final hidden layer.
#     - **Dropout Layers**: Introduced dropout layers to prevent overfitting.
#
# 2. **Hyperparameters**
#     - **Learning Rate**: Adjusted the learning rate to `0.0005` for more stable training.
#     - **Optimizer**: Switched to **AdamW** for effective weight decay (L2 regularization).
#     - **Batch Size**: Set to `64` for balanced updates.
#     - **Epochs**: Increased to `10` for improved convergence and performance.
#
# 3. **Class Imbalance**
#     - Addressed class imbalance using **SMOTE** to oversample minority classes and ensure balanced training.
#
# 4. **Data Augmentation**
#     - Continued to use **normalized and augmented training data** for improved generalization.

# %% [markdown]
# #### 2.5.2 Optimized Neural Network

# %%
# Check if a GPU is available for faster computations, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Function to load batches of data from saved files
def load_batches(batch_prefix):
    for batch_file in sorted(glob.glob(f"{batch_prefix}_batch_*.pkl")):
        with open(batch_file, "rb") as f:
            batch_data, batch_labels = pickle.load(f)
            yield batch_data, batch_labels

# Function to oversample data using SMOTE to handle class imbalance
def oversample_with_smote(data, labels):
    smote = SMOTE(random_state=42)
    data_resampled, labels_resampled = smote.fit_resample(data, labels)
    return data_resampled, labels_resampled

# Define the Neural Network Model
class OptimizedNeuralNetwork(nn.Module):
    def __init__(self):
        super(OptimizedNeuralNetwork, self).__init__()
        # Define layers for the neural network
        self.fc = nn.Sequential(
            nn.Linear(64 * 64 * 3, 512),  
            nn.LeakyReLU(),  
            nn.Dropout(0.3),  
            nn.Linear(512, 256),
            nn.LeakyReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Sigmoid()  
        )

    def forward(self, x):
        return self.fc(x)

# Instantiate the model and send it to the device (GPU or CPU)
model = OptimizedNeuralNetwork().to(device)
criterion = nn.BCELoss()    # Define the loss function (measures how wrong predictions are), Binary Cross Entropy for binary classification
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=1e-5)  # Define the optimizer (helps the model learn during training)
BATCH_SIZE = 64
EPOCHS = 30

# Training the model
print("Training Optimized Neural Network with Batches...")
model.train()
for epoch in range(EPOCHS):
    print(f"Epoch {epoch + 1}/{EPOCHS}")
    for train_batch, train_labels_batch in load_batches("train_normalized_augmented"):
        train_batch = torch.tensor(train_batch, dtype=torch.float32).to(device)
        train_labels_batch = torch.tensor(train_labels_batch, dtype=torch.float32).view(-1, 1).to(device)
        outputs = model(train_batch)
        loss = criterion(outputs, train_labels_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch + 1} completed. Loss: {loss.item():.4f}")

print("Optimized Neural Network training completed.")


# Evaluate the model on the validation dataset
print("Evaluating on Validation Set...")
model.eval()

# Store all validation labels, predictions, and probabilities for evaluation
all_val_labels = []
all_val_predictions = []
all_val_probabilities = []

with torch.no_grad():
    for val_batch, val_labels_batch in load_batches("val_normalized_augmented"):
        val_batch = torch.tensor(val_batch, dtype=torch.float32).to(device)
        val_labels_batch = np.array(val_labels_batch)
        probabilities = model(val_batch).cpu().numpy().flatten()
        predictions = (probabilities > 0.5).astype(int)  #threshold of 0.5
        all_val_labels.extend(val_labels_batch)
        all_val_predictions.extend(predictions)
        all_val_probabilities.extend(probabilities)
        
# Convert all validation results to numpy arrays for easier processing
all_val_labels = np.array(all_val_labels)
all_val_predictions = np.array(all_val_predictions)
all_val_probabilities = np.array(all_val_probabilities)


accuracy = accuracy_score(all_val_labels, all_val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(all_val_labels, all_val_predictions, target_names=["Negative", "Positive"]))

conf_matrix = confusion_matrix(all_val_labels, all_val_predictions)
print("Confusion Matrix:")
print(conf_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

precision, recall, _ = precision_recall_curve(all_val_labels, all_val_probabilities)
pr_auc = auc(recall, precision)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f"PR Curve (AUC = {pr_auc:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

fpr, tpr, _ = roc_curve(all_val_labels, all_val_probabilities)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Save the trained model to a file
torch.save(model.state_dict(), "optimized_neural_network_model.pth")
print("Optimized Neural Network model saved.")
# Out:
# Training Optimized Neural Network with Batches...
# Epoch 1/30
# Epoch 1 completed. Loss: 0.5816
# Epoch 2/30
# Epoch 2 completed. Loss: 0.5485
# Epoch 3/30
# Epoch 3 completed. Loss: 0.5479
# Epoch 4/30
# Epoch 4 completed. Loss: 0.5662
# Epoch 5/30
# Epoch 5 completed. Loss: 0.5691
# Epoch 6/30
# Epoch 6 completed. Loss: 0.5590
# Epoch 7/30
# Epoch 7 completed. Loss: 0.5459
# Epoch 8/30
# Epoch 8 completed. Loss: 0.5421
# Epoch 9/30
# Epoch 9 completed. Loss: 0.5575
# Epoch 10/30
# Epoch 10 completed. Loss: 0.5332
# Epoch 11/30
# Epoch 11 completed. Loss: 0.5461
# Epoch 12/30
# Epoch 12 completed. Loss: 0.5474
# Epoch 13/30
# Epoch 13 completed. Loss: 0.5544
# Epoch 14/30
# Epoch 14 completed. Loss: 0.5365
# Epoch 15/30
# Epoch 15 completed. Loss: 0.5323
# Epoch 16/30
# Epoch 16 completed. Loss: 0.5591
# Epoch 17/30
# Epoch 17 completed. Loss: 0.5273
# Epoch 18/30
# Epoch 18 completed. Loss: 0.5409
# Epoch 19/30
# Epoch 19 completed. Loss: 0.5494
# Epoch 20/30
# Epoch 20 completed. Loss: 0.5464
# Epoch 21/30
# Epoch 21 completed. Loss: 0.4981
# Epoch 22/30
# Epoch 22 completed. Loss: 0.5306
# Epoch 23/30
# Epoch 23 completed. Loss: 0.5484
# Epoch 24/30
# Epoch 24 completed. Loss: 0.5473
# Epoch 25/30
# Epoch 25 completed. Loss: 0.5095
# Epoch 26/30
# Epoch 26 completed. Loss: 0.5188
# Epoch 27/30
# Epoch 27 completed. Loss: 0.5194
# Epoch 28/30
# Epoch 28 completed. Loss: 0.5442
# Epoch 29/30
# Epoch 29 completed. Loss: 0.5251
# Epoch 30/30
# Epoch 30 completed. Loss: 0.5343
# Optimized Neural Network training completed.
# Evaluating on Validation Set...
# Validation Accuracy: 0.77
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.80      0.81     26182
#     Positive       0.71      0.73      0.72     17823
#
#     accuracy                           0.77     44005
#    macro avg       0.76      0.77      0.76     44005
# weighted avg       0.77      0.77      0.77     44005
#
# Confusion Matrix:
# [[20842  5340]
#  [ 4726 13097]]
# Optimized Neural Network model saved.

# %% [markdown]
# ### 2.6 XGBoost

# %% [markdown]
# 1. **Key Features**
#     - Gradient boosting framework for tree-based models.
#     - Optimized for speed and accuracy.
# 2. **Hyperparameters**
#     - **Learning Rate**: 0.1
#     - **Max.depth**: 6
#     - **Subsample**: 0.8
#     - **Trees**: 100
# 3. **Strength**
#     - Robust to overfitting and handles class imbalance well.
# 4. **Limitations**
#     - Complexity in hyperparameter tuning.

# %%
# Load training data and labels from a saved file
with open("train_images_raw.pkl", "rb") as f:
    train_data, train_labels = pickle.load(f)
    
# Load validation data and labels from a saved file
with open("val_images_raw.pkl", "rb") as f:
    val_data, val_labels = pickle.load(f)

# Create an XGBoost classifier model with specific settings
xgb_model = XGBClassifier(
    n_estimators=100,       # Number of trees (boosting rounds)   
    learning_rate=0.1,       # Step size for updating weights during training   
    max_depth=6,              # Maximum depth of each tree  
    objective="binary:logistic",   # Task type (binary classification with probabilities)
    random_state=42            
)

# Train the model using the training data
print("Training XGBoost...")
xgb_model.fit(
    train_data, train_labels,
    eval_set=[(val_data, val_labels)],  
    verbose=True                       
)
print("XGBoost training completed.")

# print("Evaluating on Validation Set...")
# Make predictions on the validation data
val_predictions = xgb_model.predict(val_data)
val_probabilities = xgb_model.predict_proba(val_data)[:, 1] 

accuracy = accuracy_score(val_labels, val_predictions)
print(f"Validation Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(val_labels, val_predictions, target_names=["Negative", "Positive"]))
conf_matrix = confusion_matrix(val_labels, val_predictions)
print("Confusion Matrix:")
print(conf_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
precision, recall, _ = precision_recall_curve(val_labels, val_probabilities)
pr_auc = auc(recall, precision)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f"PR Curve (AUC = {pr_auc:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

fpr, tpr, _ = roc_curve(val_labels, val_probabilities)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
dump(xgb_model, "xgboost_model_no_eval_metric.joblib")
print("XGBoost model saved.")
# Out:
# Training XGBoost...
# [0]	validation_0-logloss:0.65925
# [1]	validation_0-logloss:0.64469
# [2]	validation_0-logloss:0.63178
# [3]	validation_0-logloss:0.62016
# [4]	validation_0-logloss:0.60974
# [5]	validation_0-logloss:0.59995
# [6]	validation_0-logloss:0.59107
# [7]	validation_0-logloss:0.58296
# [8]	validation_0-logloss:0.57558
# [9]	validation_0-logloss:0.56886
# [10]	validation_0-logloss:0.56268
# [11]	validation_0-logloss:0.55669
# [12]	validation_0-logloss:0.55128
# [13]	validation_0-logloss:0.54635
# [14]	validation_0-logloss:0.54168
# [15]	validation_0-logloss:0.53731
# [16]	validation_0-logloss:0.53324
# [17]	validation_0-logloss:0.52941
# [18]	validation_0-logloss:0.52583
# [19]	validation_0-logloss:0.52236
# [20]	validation_0-logloss:0.51919
# [21]	validation_0-logloss:0.51606
# [22]	validation_0-logloss:0.51321
# [23]	validation_0-logloss:0.51059
# [24]	validation_0-logloss:0.50800
# [25]	validation_0-logloss:0.50546
# [26]	validation_0-logloss:0.50297
# [27]	validation_0-logloss:0.50070
# [28]	validation_0-logloss:0.49863
# [29]	validation_0-logloss:0.49655
# [30]	validation_0-logloss:0.49446
# [31]	validation_0-logloss:0.49268
# [32]	validation_0-logloss:0.49080
# [33]	validation_0-logloss:0.48900
# [34]	validation_0-logloss:0.48716
# [35]	validation_0-logloss:0.48539
# [36]	validation_0-logloss:0.48365
# [37]	validation_0-logloss:0.48209
# [38]	validation_0-logloss:0.48057
# [39]	validation_0-logloss:0.47905
# [40]	validation_0-logloss:0.47749
# [41]	validation_0-logloss:0.47609
# [42]	validation_0-logloss:0.47483
# [43]	validation_0-logloss:0.47342
# [44]	validation_0-logloss:0.47203
# [45]	validation_0-logloss:0.47072
# [46]	validation_0-logloss:0.46948
# [47]	validation_0-logloss:0.46825
# [48]	validation_0-logloss:0.46707
# [49]	validation_0-logloss:0.46573
# [50]	validation_0-logloss:0.46450
# [51]	validation_0-logloss:0.46349
# [52]	validation_0-logloss:0.46250
# [53]	validation_0-logloss:0.46140
# [54]	validation_0-logloss:0.46039
# [55]	validation_0-logloss:0.45948
# [56]	validation_0-logloss:0.45837
# [57]	validation_0-logloss:0.45746
# [58]	validation_0-logloss:0.45654
# [59]	validation_0-logloss:0.45562
# [60]	validation_0-logloss:0.45467
# [61]	validation_0-logloss:0.45372
# [62]	validation_0-logloss:0.45271
# [63]	validation_0-logloss:0.45186
# [64]	validation_0-logloss:0.45095
# [65]	validation_0-logloss:0.45015
# [66]	validation_0-logloss:0.44937
# [67]	validation_0-logloss:0.44848
# [68]	validation_0-logloss:0.44761
# [69]	validation_0-logloss:0.44690
# [70]	validation_0-logloss:0.44612
# [71]	validation_0-logloss:0.44546
# [72]	validation_0-logloss:0.44467
# [73]	validation_0-logloss:0.44387
# [74]	validation_0-logloss:0.44314
# [75]	validation_0-logloss:0.44236
# [76]	validation_0-logloss:0.44166
# [77]	validation_0-logloss:0.44085
# [78]	validation_0-logloss:0.44015
# [79]	validation_0-logloss:0.43951
# [80]	validation_0-logloss:0.43879
# [81]	validation_0-logloss:0.43811
# [82]	validation_0-logloss:0.43740
# [83]	validation_0-logloss:0.43686
# [84]	validation_0-logloss:0.43620
# [85]	validation_0-logloss:0.43565
# [86]	validation_0-logloss:0.43510
# [87]	validation_0-logloss:0.43445
# [88]	validation_0-logloss:0.43387
# [89]	validation_0-logloss:0.43338
# [90]	validation_0-logloss:0.43277
# [91]	validation_0-logloss:0.43212
# [92]	validation_0-logloss:0.43155
# [93]	validation_0-logloss:0.43098
# [94]	validation_0-logloss:0.43042
# [95]	validation_0-logloss:0.42986
# [96]	validation_0-logloss:0.42930
# [97]	validation_0-logloss:0.42884
# [98]	validation_0-logloss:0.42839
# [99]	validation_0-logloss:0.42796
# XGBoost training completed.
# Evaluating on Validation Set...
# Validation Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.86      0.84     26182
#     Positive       0.78      0.73      0.76     17823
#
#     accuracy                           0.81     44005
#    macro avg       0.80      0.80      0.80     44005
# weighted avg       0.81      0.81      0.81     44005
#
# Confusion Matrix:
# [[22531  3651]
#  [ 4756 13067]]
# XGBoost model saved.

# %% [markdown]
# ## 3 Models Comparison

# %%
metrics_summary = {
    "Model": [
        "Naive Bayes",
        "Random Forest",
        "Logistic Regression",
        "SVM",
        "Neural Network",
        "XGBoost"
    ],
    "Accuracy": [0.73, 0.75, 0.63, 0.76, 0.77, 0.81],
    "Precision": [0.75, 0.76, 0.62, 0.77, 0.77, 0.81],
    "Recall": [0.73, 0.75, 0.63, 0.76, 0.77, 0.81],
    "F1-score": [0.73, 0.74, 0.62, 0.77, 0.77, 0.81]
}

metrics_df = pd.DataFrame(metrics_summary)
metrics_melted = pd.melt(
    metrics_df,
    id_vars="Model",
    value_vars=["Accuracy", "Precision", "Recall", "F1-score"],
    var_name="Metric",
    value_name="Score"
)

plt.figure(figsize=(12, 8))
sns.barplot(
    data=metrics_melted,
    x="Metric",
    y="Score",
    hue="Model",
    palette="viridis"
)


plt.title("Model Comparison by Metric", fontsize=16)
plt.ylabel("Score", fontsize=12)
plt.xlabel("Metric", fontsize=12)
plt.ylim(0.5, 1.0)  
plt.xticks(fontsize=10)
plt.legend(title="Model", bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Future Improvements
#
# 1. **Neural Network**
#     - Experiment with different loss functions (e.g., focal loss to address class imbalance).
#     - Dynamically adjust the learning rate using schedulers.
#     - Increase the number of epochs for extended training.
#
# 2. **XGBoost**
#     - Fine-tune hyperparameters (e.g., tree depth, subsampling rates).
#     - Incorporate custom objective functions to better handle class imbalance.

# %% [markdown]
# ### Real-World Application
#  - Cancer is one of the leading causes of death worldwide. Early detection of metastatic cancer through histopathologic analysis can significantly improve treatment outcomes. This project demonstrates how modern AI techniques, particularly neural networks and ensemble methods, can enhance the accuracy and speed of cancer detection. By leveraging technology, we aim to aid medical professionals in making faster and more reliable diagnoses, ultimately contributing to better patient care and outcomes.
#  - This work highlights the potential of machine learning to revolutionize healthcare and make a meaningful impact on human lives.

# %% [markdown]
# ### Contribution of Team Members
#
# 1. **Jing Wang:**
#     - Responsible for data preprocessing, all model training, combining works of other teammates, comparison, and report writing.
#
# 2. **Vikash Bajiya:**
#     - Responsible for data preprocessing, model training (Logistic regression & SVM), report writing and presentation preparation.
#
# 3.  **Deviprasad Saka**
#     - Responsible for data preprocessing, model training (Naive Bayes & Random Forest), report writing and presentation preparation.
